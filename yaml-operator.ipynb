# %%
# Definitions
# This script is used to generate a file tree from terraform modules in yaml format.
# 
# Dependencies:
# - PyYAML
# - python-hcl2
#
# Files located in the gen3-terraform/tf_files directory are used to generate improperly formatted yaml files in the same location.
# In terraform, files are grouped into different directories based on their purpose.
# This allows for better organization and easier navigation of the codebase.
# 
# In future releases, intermediary files will be deleted upon successful generation of the yaml tree.  
# 
# 
# Terraform complete folder
terraform_folder="gen3-terraform/tf_files"
# Intermediary folder for equivalent yaml files in the same location as terraform files
yaml_folder="yaml_files"
# Equivalent Terraform initialization folder
yaml_exec_source="yaml_files/aws/commons"
yaml_exec_tree="yaml_tree"

# %% [markdown]
# ### Copy all **non-tf** files in directory to the yaml file directory

# %%
#!/usr/bin/env python3
"""
copy_non_tf.py

Copies all files under SOURCE_DIR that do NOT end with .tf
to DEST_DIR, preserving the directory structure.
"""

import os
import shutil
import sys

def copy_non_tf(source_dir, dest_dir):
    source_dir = os.path.abspath(source_dir)
    for root, _, files in os.walk(source_dir):
        # Compute relative path from the source root
        rel_dir = os.path.relpath(root, source_dir)
        for fname in files:
            if not fname.endswith('.tf'):
                src_path = os.path.join(root, fname)
                # Build the corresponding destination path
                target_dir = os.path.join(dest_dir, rel_dir)
                os.makedirs(target_dir, exist_ok=True)
                dst_path = os.path.join(target_dir, fname)
                shutil.copy2(src_path, dst_path)
                print(f"Copied: {src_path} → {dst_path}")

copy_non_tf(terraform_folder, yaml_folder)
# Out:
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\README.md → yaml_files\.\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\access\manifest.json → yaml_files\aws\access\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\access\sample.tfvars → yaml_files\aws\access\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\manifest.json → yaml_files\aws\account-policies\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\README.md → yaml_files\aws\account-policies\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\sample.tfvars → yaml_files\aws\account-policies\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\custom_iam_policies\Cloud_Logging.json → yaml_files\aws\account-policies\custom_iam_policies\Cloud_Logging.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\custom_iam_policies\Config_Read_List.json → yaml_files\aws\account-policies\custom_iam_policies\Config_Read_List.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\custom_iam_policies\CtdsKmsSuper.json → yaml_files\aws\account-policies\custom_iam_policies\CtdsKmsSuper.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\custom_iam_policies\DevOPSConsolidatedPolicies.json → yaml_files\aws\account-policies\custom_iam_policies\DevOPSConsolidatedPolicies.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\custom_iam_policies\DevOpsDirectorConsolidatedPolicies.json → yaml_files\aws\account-policies\custom_iam_policies\DevOpsDirectorConsolidatedPolicies.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\custom_iam_policies\DevOpsTroubleShooting_CLIFunctions.json → yaml_files\aws\account-policies\custom_iam_policies\DevOpsTroubleShooting_CLIFunctions.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\custom_iam_policies\IAMConsoleListings.json → yaml_files\aws\account-policies\custom_iam_policies\IAMConsoleListings.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\custom_iam_policies\Logs_Read.json → yaml_files\aws\account-policies\custom_iam_policies\Logs_Read.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\metadata\saml-metadata.xml → yaml_files\aws\account-policies\metadata\saml-metadata.xml
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\manifest.json → yaml_files\aws\account_management-logs\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\sample.tfvars → yaml_files\aws\account_management-logs\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\manifest.json → yaml_files\aws\aurora\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\db_setup.tftpl → yaml_files\aws\aurora_db\db_setup.tftpl
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\manifest.json → yaml_files\aws\aurora_db\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\secrets_manager.tftpl → yaml_files\aws\aurora_db\secrets_manager.tftpl
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\batch\manifest.json → yaml_files\aws\batch\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\batch\sample.tfvars → yaml_files\aws\batch\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\manifest.json → yaml_files\aws\bucket_manifest_utils\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\sample.tfvars → yaml_files\aws\bucket_manifest_utils\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\manifest.json → yaml_files\aws\cognito\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\README.md → yaml_files\aws\cognito\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\sample.tfvars → yaml_files\aws\cognito\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\cluster.yaml → yaml_files\aws\commons\cluster.yaml
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\kube-up-body.sh → yaml_files\aws\commons\kube-up-body.sh
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\manifest.json → yaml_files\aws\commons\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\README.md → yaml_files\aws\commons\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\sample.tfvars → yaml_files\aws\commons\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons_vpc_es\manifest.json → yaml_files\aws\commons_vpc_es\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons_vpc_es\sample.tfvars → yaml_files\aws\commons_vpc_es\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\csoc_admin_vm\manifest.json → yaml_files\aws\csoc_admin_vm\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\csoc_admin_vm\sample.tfvars → yaml_files\aws\csoc_admin_vm\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\csoc_common_logging\manifest.json → yaml_files\aws\csoc_common_logging\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\csoc_common_logging\sample.tfvars → yaml_files\aws\csoc_common_logging\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\csoc_management-logs\manifest.json → yaml_files\aws\csoc_management-logs\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\csoc_management-logs\sample.tfvars → yaml_files\aws\csoc_management-logs\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\datadog\manifest.json → yaml_files\aws\datadog\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\datadog\sample.tfvars → yaml_files\aws\datadog\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\datadog_api_monitor\manifest.json → yaml_files\aws\datadog_api_monitor\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\data_bucket\manifest.json → yaml_files\aws\data_bucket\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\data_bucket\README.md → yaml_files\aws\data_bucket\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\data_bucket\sample.tfvars → yaml_files\aws\data_bucket\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\data_bucket_queue\manifest.json → yaml_files\aws\data_bucket_queue\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\data_bucket_queue\sample.tfvars → yaml_files\aws\data_bucket_queue\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\db_reencrypt\manifest.json → yaml_files\aws\db_reencrypt\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\eks\manifest.json → yaml_files\aws\eks\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\eks\sample.tfvars → yaml_files\aws\eks\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\generic_commons\README.md → yaml_files\aws\generic_commons\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\account-management-logs\README.md → yaml_files\aws\modules\account-management-logs\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\admin-vm\README.md → yaml_files\aws\modules\admin-vm\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\common-logging\lambda_function.py → yaml_files\aws\modules\common-logging\lambda_function.py
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\common-logging\README.md → yaml_files\aws\modules\common-logging\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\common-logging\testLambda.py → yaml_files\aws\modules\common-logging\testLambda.py
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\common-logging\workflow.png → yaml_files\aws\modules\common-logging\workflow.png
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\common-logging\workflow.svg → yaml_files\aws\modules\common-logging\workflow.svg
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\commons-sns\README.md → yaml_files\aws\modules\commons-sns\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\commons-vpc-es\README.md → yaml_files\aws\modules\commons-vpc-es\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\data-bucket-queue\README.md → yaml_files\aws\modules\data-bucket-queue\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\data-bucket-queue\sample.tfvars → yaml_files\aws\modules\data-bucket-queue\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\eks\init_cluster.sh → yaml_files\aws\modules\eks\init_cluster.sh
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\eks\kubeconfig.tpl → yaml_files\aws\modules\eks\kubeconfig.tpl
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\eks\lambda_function.py → yaml_files\aws\modules\eks\lambda_function.py
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\eks\README.md → yaml_files\aws\modules\eks\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\eks-nodepool\README.md → yaml_files\aws\modules\eks-nodepool\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\fence-bot-user\README.md → yaml_files\aws\modules\fence-bot-user\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\iam-policy\README.md → yaml_files\aws\modules\iam-policy\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\iam-role\README.md → yaml_files\aws\modules\iam-role\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\lambda-function\README.md → yaml_files\aws\modules\lambda-function\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\management-logs\lambda_function.py → yaml_files\aws\modules\management-logs\lambda_function.py
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\management-logs\README.md → yaml_files\aws\modules\management-logs\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\management-logs\testLambda.py → yaml_files\aws\modules\management-logs\testLambda.py
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\management-logs\workflow.png → yaml_files\aws\modules\management-logs\workflow.png
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\rds\README.md → yaml_files\aws\modules\rds\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\s3-bucket\data-explorer.svg → yaml_files\aws\modules\s3-bucket\data-explorer.svg
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\s3-bucket\README.md → yaml_files\aws\modules\s3-bucket\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\s3-logs\README.md → yaml_files\aws\modules\s3-logs\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\sqs\README.md → yaml_files\aws\modules\sqs\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\squidnlb\README.md → yaml_files\aws\modules\squidnlb\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\squid_auto\README.md → yaml_files\aws\modules\squid_auto\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\squid_nlb_central_csoc\CSOC_Centralized_Squid_Set-up.svg → yaml_files\aws\modules\squid_nlb_central_csoc\CSOC_Centralized_Squid_Set-up.svg
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\squid_nlb_central_csoc\README.md → yaml_files\aws\modules\squid_nlb_central_csoc\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\upload-data-bucket\README.md → yaml_files\aws\modules\upload-data-bucket\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\utility-vm\README.md → yaml_files\aws\modules\utility-vm\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\vpc\README.md → yaml_files\aws\modules\vpc\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\vpn_nlb_central_csoc\README.md → yaml_files\aws\modules\vpn_nlb_central_csoc\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\modules\worker-bigdisk\README.md → yaml_files\aws\modules\worker-bigdisk\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\publicvm\manifest.json → yaml_files\aws\publicvm\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\publicvm\README.md → yaml_files\aws\publicvm\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\publicvm\sample.tfvars → yaml_files\aws\publicvm\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\rds\manifest.json → yaml_files\aws\rds\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\rds\sample.tfvars → yaml_files\aws\rds\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\role\manifest.json → yaml_files\aws\role\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\role\README.md → yaml_files\aws\role\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\role\sample.tfvars → yaml_files\aws\role\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\role_policy_attachment\manifest.json → yaml_files\aws\role_policy_attachment\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\role_policy_attachment\README.md → yaml_files\aws\role_policy_attachment\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\role_policy_attachment\sample.tfvars → yaml_files\aws\role_policy_attachment\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\secrets_manager\manifest.json → yaml_files\aws\secrets_manager\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\sftp\manifest.json → yaml_files\aws\sftp\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\sftp\sample.tfvars → yaml_files\aws\sftp\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\sqs\manifest.json → yaml_files\aws\sqs\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\sqs\sample.tfvars → yaml_files\aws\sqs\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\squidnlb_standalone\manifest.json → yaml_files\aws\squidnlb_standalone\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\squidnlb_standalone\sample.tfvars → yaml_files\aws\squidnlb_standalone\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\squid_auto\manifest.json → yaml_files\aws\squid_auto\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\squid_auto\sample.tfvars → yaml_files\aws\squid_auto\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\squid_nlb_central\manifest.json → yaml_files\aws\squid_nlb_central\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\squid_nlb_central\sample.tfvars → yaml_files\aws\squid_nlb_central\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\storage-gateway\manifest.json → yaml_files\aws\storage-gateway\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\storage-gateway\README.md → yaml_files\aws\storage-gateway\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\storage-gateway\sample.tfvars → yaml_files\aws\storage-gateway\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\user_generic\manifest.json → yaml_files\aws\user_generic\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\user_generic\README.md → yaml_files\aws\user_generic\README.md
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\user_generic\sample.tfvars → yaml_files\aws\user_generic\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\utility_vm\manifest.json → yaml_files\aws\utility_vm\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\utility_vm\sample.tfvars → yaml_files\aws\utility_vm\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\vpn_nlb_central\manifest.json → yaml_files\aws\vpn_nlb_central\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\vpn_nlb_central\sample.tfvars → yaml_files\aws\vpn_nlb_central\sample.tfvars
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\waf\manifest.json → yaml_files\aws\waf\manifest.json
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\aws-user-creds.tftpl → yaml_files\gen3\aws-user-creds.tftpl
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\fence-config.tftpl → yaml_files\gen3\fence-config.tftpl
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\values.tftpl → yaml_files\gen3\values.tftpl
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\00configmap.yaml → yaml_files\shared\modules\k8s_configs\00configmap.yaml
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\creds.tpl → yaml_files\shared\modules\k8s_configs\creds.tpl
# Copied: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\kube-vars.sh.tpl → yaml_files\shared\modules\k8s_configs\kube-vars.sh.tpl

# %% [markdown]
# ### Convert and copy all .tf files and copy them to the yaml file directory

# %%
#!/usr/bin/env python3
"""
Recursively parse all .tf files in a directory and emit corresponding .tf.yaml files,
with debug logging at every step.
"""
import os
import argparse
import hcl2
import yaml

def parse_directory(src_dir: str, out_dir: str):
    # Normalize input paths
    src_dir = os.path.abspath(src_dir)
    out_dir = os.path.abspath(out_dir)
    print(f"DEBUG: Starting parse_directory")
    print(f"DEBUG:  src_dir = {src_dir}")
    print(f"DEBUG:  out_dir = {out_dir}\n")

    for root, _, files in os.walk(src_dir):
        rel = os.path.relpath(root, src_dir)
        print(f"DEBUG: Walking into directory: {root}")
        print(f"DEBUG:  Relative path = {rel}")
        print(f"DEBUG:  Files in this dir = {files}")

        for fname in files:
            print(f"\nDEBUG: Inspecting file: {fname}")
            if not fname.endswith(".tf"):
                print(f"DEBUG:  Skipping (not a .tf): {fname}")
                continue

            tf_path = os.path.join(root, fname)
            print(f"DEBUG:  Found Terraform file: {tf_path}")
            try:
                with open(tf_path, "r") as f:
                    print(f"DEBUG:    Loading HCL from {tf_path}")
                    parsed = hcl2.load(f)
                print(f"DEBUG:    HCL parsed, type(parsed)={type(parsed).__name__}")
            except Exception as e:
                print(f"ERROR:   Failed to parse {tf_path}: {e}")
                continue

            # compute output path
            out_subdir = out_dir if rel == "." else os.path.join(out_dir, rel)
            print(f"DEBUG:    out_subdir = {out_subdir}")
            os.makedirs(out_subdir, exist_ok=True)

            yaml_path = os.path.join(out_subdir, fname + ".yaml")
            print(f"DEBUG:    yaml_path = {yaml_path}")
            try:
                with open(yaml_path, "w") as yf:
                    yaml.safe_dump(parsed, yf, sort_keys=False)
                print(f"✓ Written: {tf_path} → {yaml_path}")
            except Exception as e:
                print(f"ERROR:   Failed to write YAML to {yaml_path}: {e}")

if __name__ == "__main__":
    # you can parameterize these via argparse if you like
    parse_directory(terraform_folder, yaml_folder)
# Out:
# DEBUG: Starting parse_directory
# DEBUG:  src_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files
# DEBUG:  out_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files
#
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files
# DEBUG:  Relative path = .
# DEBUG:  Files in this dir = ['README.md']
#
# DEBUG: Inspecting file: README.md
# DEBUG:  Skipping (not a .tf): README.md
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws
# DEBUG:  Relative path = aws
# DEBUG:  Files in this dir = ['root.tf', 'variables.tf']
#
# DEBUG: Inspecting file: root.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\root.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\root.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\root.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\root.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\root.tf.yaml
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\access
# DEBUG:  Relative path = aws\access
# DEBUG:  Files in this dir = ['cloud.tf', 'manifest.json', 'sample.tfvars', 'variables.tf']
#
# DEBUG: Inspecting file: cloud.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\access\cloud.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\access\cloud.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\access
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\access\cloud.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\access\cloud.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\access\cloud.tf.yaml
#
# DEBUG: Inspecting file: manifest.json
# DEBUG:  Skipping (not a .tf): manifest.json
#
# DEBUG: Inspecting file: sample.tfvars
# DEBUG:  Skipping (not a .tf): sample.tfvars
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\access\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\access\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\access
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\access\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\access\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\access\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies
# DEBUG:  Relative path = aws\account-policies
# DEBUG:  Files in this dir = ['ebs_encryption.tf', 'iam_policies.tf', 'identity_provider.tf', 'main.tf', 'manifest.json', 'README.md', 's3_public_block.tf', 'sample.tfvars', 'variables.tf']
#
# DEBUG: Inspecting file: ebs_encryption.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\ebs_encryption.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\ebs_encryption.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\ebs_encryption.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\ebs_encryption.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\ebs_encryption.tf.yaml
#
# DEBUG: Inspecting file: iam_policies.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\iam_policies.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\iam_policies.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\iam_policies.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\iam_policies.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\iam_policies.tf.yaml
#
# DEBUG: Inspecting file: identity_provider.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\identity_provider.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\identity_provider.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\identity_provider.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\identity_provider.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\identity_provider.tf.yaml
#
# DEBUG: Inspecting file: main.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\main.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\main.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\main.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\main.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\main.tf.yaml
#
# DEBUG: Inspecting file: manifest.json
# DEBUG:  Skipping (not a .tf): manifest.json
#
# DEBUG: Inspecting file: README.md
# DEBUG:  Skipping (not a .tf): README.md
#
# DEBUG: Inspecting file: s3_public_block.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\s3_public_block.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\s3_public_block.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\s3_public_block.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\s3_public_block.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\s3_public_block.tf.yaml
#
# DEBUG: Inspecting file: sample.tfvars
# DEBUG:  Skipping (not a .tf): sample.tfvars
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account-policies\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\custom_iam_policies
# DEBUG:  Relative path = aws\account-policies\custom_iam_policies
# DEBUG:  Files in this dir = ['Cloud_Logging.json', 'Config_Read_List.json', 'CtdsKmsSuper.json', 'DevOPSConsolidatedPolicies.json', 'DevOpsDirectorConsolidatedPolicies.json', 'DevOpsTroubleShooting_CLIFunctions.json', 'IAMConsoleListings.json', 'Logs_Read.json']
#
# DEBUG: Inspecting file: Cloud_Logging.json
# DEBUG:  Skipping (not a .tf): Cloud_Logging.json
#
# DEBUG: Inspecting file: Config_Read_List.json
# DEBUG:  Skipping (not a .tf): Config_Read_List.json
#
# DEBUG: Inspecting file: CtdsKmsSuper.json
# DEBUG:  Skipping (not a .tf): CtdsKmsSuper.json
#
# DEBUG: Inspecting file: DevOPSConsolidatedPolicies.json
# DEBUG:  Skipping (not a .tf): DevOPSConsolidatedPolicies.json
#
# DEBUG: Inspecting file: DevOpsDirectorConsolidatedPolicies.json
# DEBUG:  Skipping (not a .tf): DevOpsDirectorConsolidatedPolicies.json
#
# DEBUG: Inspecting file: DevOpsTroubleShooting_CLIFunctions.json
# DEBUG:  Skipping (not a .tf): DevOpsTroubleShooting_CLIFunctions.json
#
# DEBUG: Inspecting file: IAMConsoleListings.json
# DEBUG:  Skipping (not a .tf): IAMConsoleListings.json
#
# DEBUG: Inspecting file: Logs_Read.json
# DEBUG:  Skipping (not a .tf): Logs_Read.json
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account-policies\metadata
# DEBUG:  Relative path = aws\account-policies\metadata
# DEBUG:  Files in this dir = ['saml-metadata.xml']
#
# DEBUG: Inspecting file: saml-metadata.xml
# DEBUG:  Skipping (not a .tf): saml-metadata.xml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs
# DEBUG:  Relative path = aws\account_management-logs
# DEBUG:  Files in this dir = ['manifest.json', 'outputs.tf', 'root.tf', 'sample.tfvars', 'variables.tf']
#
# DEBUG: Inspecting file: manifest.json
# DEBUG:  Skipping (not a .tf): manifest.json
#
# DEBUG: Inspecting file: outputs.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\outputs.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\outputs.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account_management-logs
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account_management-logs\outputs.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\outputs.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account_management-logs\outputs.tf.yaml
#
# DEBUG: Inspecting file: root.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\root.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\root.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account_management-logs
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account_management-logs\root.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\root.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account_management-logs\root.tf.yaml
#
# DEBUG: Inspecting file: sample.tfvars
# DEBUG:  Skipping (not a .tf): sample.tfvars
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account_management-logs
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account_management-logs\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\account_management-logs\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\account_management-logs\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora
# DEBUG:  Relative path = aws\aurora
# DEBUG:  Files in this dir = ['manifest.json', 'output.tf', 'root.tf', 'variables.tf']
#
# DEBUG: Inspecting file: manifest.json
# DEBUG:  Skipping (not a .tf): manifest.json
#
# DEBUG: Inspecting file: output.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\output.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\output.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora\output.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\output.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora\output.tf.yaml
#
# DEBUG: Inspecting file: root.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\root.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\root.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora\root.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\root.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora\root.tf.yaml
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db
# DEBUG:  Relative path = aws\aurora_db
# DEBUG:  Files in this dir = ['data.tf', 'db_setup.tftpl', 'manifest.json', 'root.tf', 'secrets_manager.tftpl', 'variables.tf']
#
# DEBUG: Inspecting file: data.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\data.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\data.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db\data.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\data.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db\data.tf.yaml
#
# DEBUG: Inspecting file: db_setup.tftpl
# DEBUG:  Skipping (not a .tf): db_setup.tftpl
#
# DEBUG: Inspecting file: manifest.json
# DEBUG:  Skipping (not a .tf): manifest.json
#
# DEBUG: Inspecting file: root.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\root.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\root.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db\root.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\root.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db\root.tf.yaml
#
# DEBUG: Inspecting file: secrets_manager.tftpl
# DEBUG:  Skipping (not a .tf): secrets_manager.tftpl
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\aurora_db\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\batch
# DEBUG:  Relative path = aws\batch
# DEBUG:  Files in this dir = ['manifest.json', 'root.tf', 'sample.tfvars', 'variables.tf']
#
# DEBUG: Inspecting file: manifest.json
# DEBUG:  Skipping (not a .tf): manifest.json
#
# DEBUG: Inspecting file: root.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\batch\root.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\batch\root.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\batch
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\batch\root.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\batch\root.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\batch\root.tf.yaml
#
# DEBUG: Inspecting file: sample.tfvars
# DEBUG:  Skipping (not a .tf): sample.tfvars
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\batch\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\batch\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\batch
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\batch\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\batch\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\batch\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils
# DEBUG:  Relative path = aws\bucket_manifest_utils
# DEBUG:  Files in this dir = ['manifest.json', 'outputs.tf', 'root.tf', 'sample.tfvars', 'variables.tf']
#
# DEBUG: Inspecting file: manifest.json
# DEBUG:  Skipping (not a .tf): manifest.json
#
# DEBUG: Inspecting file: outputs.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\outputs.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\outputs.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\bucket_manifest_utils
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\bucket_manifest_utils\outputs.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\outputs.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\bucket_manifest_utils\outputs.tf.yaml
#
# DEBUG: Inspecting file: root.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\root.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\root.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\bucket_manifest_utils
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\bucket_manifest_utils\root.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\root.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\bucket_manifest_utils\root.tf.yaml
#
# DEBUG: Inspecting file: sample.tfvars
# DEBUG:  Skipping (not a .tf): sample.tfvars
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\bucket_manifest_utils
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\bucket_manifest_utils\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\bucket_manifest_utils\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\bucket_manifest_utils\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito
# DEBUG:  Relative path = aws\cognito
# DEBUG:  Files in this dir = ['main.tf', 'manifest.json', 'output.tf', 'README.md', 'sample.tfvars', 'variables.tf']
#
# DEBUG: Inspecting file: main.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\main.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\main.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\cognito
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\cognito\main.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\main.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\cognito\main.tf.yaml
#
# DEBUG: Inspecting file: manifest.json
# DEBUG:  Skipping (not a .tf): manifest.json
#
# DEBUG: Inspecting file: output.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\output.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\output.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\cognito
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\cognito\output.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\output.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\cognito\output.tf.yaml
#
# DEBUG: Inspecting file: README.md
# DEBUG:  Skipping (not a .tf): README.md
#
# DEBUG: Inspecting file: sample.tfvars
# DEBUG:  Skipping (not a .tf): sample.tfvars
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\cognito
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\cognito\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\cognito\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\cognito\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons
# DEBUG:  Relative path = aws\commons
# DEBUG:  Files in this dir = ['aurora.tf', 'cloud.tf', 'cluster.yaml', 'data.tf', 'eks.tf', 'es.tf', 'helm.tf', 'kube-up-body.sh', 'kube.tf', 'manifest.json', 'outputs.tf', 'passwords.tf', 'provider.tf', 'README.md', 'sample.tfvars', 'variables.tf', 'waf.tf']
#
# DEBUG: Inspecting file: aurora.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\aurora.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\aurora.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\aurora.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\aurora.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\aurora.tf.yaml
#
# DEBUG: Inspecting file: cloud.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\cloud.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\cloud.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\cloud.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\cloud.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\cloud.tf.yaml
#
# DEBUG: Inspecting file: cluster.yaml
# DEBUG:  Skipping (not a .tf): cluster.yaml
#
# DEBUG: Inspecting file: data.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\data.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\data.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\data.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\data.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\data.tf.yaml
#
# DEBUG: Inspecting file: eks.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\eks.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\eks.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\eks.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\eks.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\eks.tf.yaml
#
# DEBUG: Inspecting file: es.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\es.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\es.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\es.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\es.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\es.tf.yaml
#
# DEBUG: Inspecting file: helm.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\helm.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\helm.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\helm.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\helm.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\helm.tf.yaml
#
# DEBUG: Inspecting file: kube-up-body.sh
# DEBUG:  Skipping (not a .tf): kube-up-body.sh
#
# DEBUG: Inspecting file: kube.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\kube.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\kube.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\kube.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\kube.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\kube.tf.yaml
#
# DEBUG: Inspecting file: manifest.json
# DEBUG:  Skipping (not a .tf): manifest.json
#
# DEBUG: Inspecting file: outputs.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\outputs.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\outputs.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\outputs.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\outputs.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\outputs.tf.yaml
#
# DEBUG: Inspecting file: passwords.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\passwords.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\passwords.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\passwords.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\passwords.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\passwords.tf.yaml
#
# DEBUG: Inspecting file: provider.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\provider.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\commons\provider.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\provider.tf.yaml
# ...
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\waf\output.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\waf\output.tf.yaml
#
# DEBUG: Inspecting file: root.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\waf\root.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\waf\root.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\waf
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\waf\root.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\waf\root.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\waf\root.tf.yaml
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\waf\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\waf\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\waf
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\waf\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\aws\waf\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\waf\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3
# DEBUG:  Relative path = gen3
# DEBUG:  Files in this dir = ['aws-user-creds.tftpl', 'data.tf', 'db.tf', 'fence-config.tftpl', 'root.tf', 's3.tf', 'secrets.tf', 'service-accounts.tf', 'sqs.tf', 'values.tftpl', 'variables.tf']
#
# DEBUG: Inspecting file: aws-user-creds.tftpl
# DEBUG:  Skipping (not a .tf): aws-user-creds.tftpl
#
# DEBUG: Inspecting file: data.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\data.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\data.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\data.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\data.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\data.tf.yaml
#
# DEBUG: Inspecting file: db.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\db.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\db.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\db.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\db.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\db.tf.yaml
#
# DEBUG: Inspecting file: fence-config.tftpl
# DEBUG:  Skipping (not a .tf): fence-config.tftpl
#
# DEBUG: Inspecting file: root.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\root.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\root.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\root.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\root.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\root.tf.yaml
#
# DEBUG: Inspecting file: s3.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\s3.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\s3.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\s3.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\s3.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\s3.tf.yaml
#
# DEBUG: Inspecting file: secrets.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\secrets.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\secrets.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\secrets.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\secrets.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\secrets.tf.yaml
#
# DEBUG: Inspecting file: service-accounts.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\service-accounts.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\service-accounts.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\service-accounts.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\service-accounts.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\service-accounts.tf.yaml
#
# DEBUG: Inspecting file: sqs.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\sqs.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\sqs.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\sqs.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\sqs.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\sqs.tf.yaml
#
# DEBUG: Inspecting file: values.tftpl
# DEBUG:  Skipping (not a .tf): values.tftpl
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\gen3\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3\variables.tf.yaml
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared
# DEBUG:  Relative path = shared
# DEBUG:  Files in this dir = []
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules
# DEBUG:  Relative path = shared\modules
# DEBUG:  Files in this dir = []
# DEBUG: Walking into directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs
# DEBUG:  Relative path = shared\modules\k8s_configs
# DEBUG:  Files in this dir = ['00configmap.yaml', 'creds.tpl', 'kube-vars.sh.tpl', 'outputs.tf', 'root.tf', 'variables.tf']
#
# DEBUG: Inspecting file: 00configmap.yaml
# DEBUG:  Skipping (not a .tf): 00configmap.yaml
#
# DEBUG: Inspecting file: creds.tpl
# DEBUG:  Skipping (not a .tf): creds.tpl
#
# DEBUG: Inspecting file: kube-vars.sh.tpl
# DEBUG:  Skipping (not a .tf): kube-vars.sh.tpl
#
# DEBUG: Inspecting file: outputs.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\outputs.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\outputs.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs\outputs.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\outputs.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs\outputs.tf.yaml
#
# DEBUG: Inspecting file: root.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\root.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\root.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs\root.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\root.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs\root.tf.yaml
#
# DEBUG: Inspecting file: variables.tf
# DEBUG:  Found Terraform file: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\variables.tf
# DEBUG:    Loading HCL from c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\variables.tf
# DEBUG:    HCL parsed, type(parsed)=dict
# DEBUG:    out_subdir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs
# DEBUG:    yaml_path = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs\variables.tf.yaml
# ✓ Written: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\gen3-terraform\tf_files\shared\modules\k8s_configs\variables.tf → c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs\variables.tf.yaml

# %% [markdown]
# ### Get the Yaml terraform source and **rebuild the tree in a new location**

# %%
import os
import shutil
import yaml
from typing import Any, List, Tuple

def extract_sources(data: Any, ctx: str = "") -> List[Tuple[str, str]]:
    """
    Recursively walk a loaded YAML data structure, returning a list of
    (source_value, context_path) for every 'source' key found.
    """
    found = []
    if isinstance(data, dict):
        for k, v in data.items():
            path = f"{ctx}.{k}" if ctx else k
            if k == "source" and isinstance(v, str):
                found.append((v, path))
            else:
                found += extract_sources(v, path)
    elif isinstance(data, list):
        for idx, item in enumerate(data):
            path = f"{ctx}[{idx}]"
            found += extract_sources(item, path)
    return found

def group_yaml_by_source(input_dir: str, output_dir: str):
    input_dir = os.path.abspath(input_dir)
    output_dir = os.path.abspath(output_dir)
    print(f"DEBUG: Normalized input_dir = {input_dir}")
    print(f"DEBUG: Normalized output_dir = {output_dir}")
    os.makedirs(output_dir, exist_ok=True)

    print(f"\nDEBUG: Scanning directory: {input_dir}")
    for entry in os.listdir(input_dir):
        full_entry = os.path.join(input_dir, entry)
        rel_entry = os.path.relpath(full_entry, input_dir)

        if not entry.lower().endswith(('.yml', '.yaml')):
            print(f"DEBUG: └─ Skipping non-YAML ({rel_entry})")
            continue

        print(f"DEBUG: └─ Found YAML file: {rel_entry}")
        try:
            with open(full_entry, 'r') as f:
                data = yaml.safe_load(f) or {}
        except yaml.YAMLError as e:
            print(f"DEBUG:     YAML parse error in {rel_entry}, skipping: {e}")
            continue

        sources = extract_sources(data)
        if not sources:
            print(f"DEBUG:     No 'source:' keys found in {rel_entry}")
            continue

        print(f"DEBUG:     sources found in {rel_entry}:")
        for src_val, ctx_path in sources:
            print(f"DEBUG:       • {ctx_path} → {src_val!r}")

        for src_val, ctx_path in sources:
            print(f"\nDEBUG:     Processing source: {src_val!r} (at {ctx_path})")

            # compute absolute path to the child folder
            src_folder = os.path.normpath(os.path.join(input_dir, src_val))
            rel_src = os.path.relpath(src_folder, input_dir)
            print(f"DEBUG:       Absolute src_folder = {src_folder}")
            print(f"DEBUG:       Relative src_folder = {rel_src}")

            # strip any leading '..' for output path
            parts = [p for p in src_val.replace('\\','/').split('/') if p != '..']
            if not parts:
                # base case: the source was just ../.. etc.
                # so we copy straight into the root of output_dir
                dest_folder = output_dir
                print("DEBUG:       Base-case source (only '..'); using output_dir as dest_folder")
            else:
                # normal case: rebuild the subpath under output_dir
                dest_folder = os.path.join(output_dir, *parts)

            print(f"DEBUG:       Computed dest_folder = {dest_folder}")
            os.makedirs(dest_folder, exist_ok=True)

            if not os.path.isdir(src_folder):
                print(f"DEBUG:       src_folder {rel_src} is not a directory; skipping copy.")
                continue

            # copy entire contents
            for root, dirs, files in os.walk(src_folder):
                rel_sub = os.path.relpath(root, src_folder)
                target_root = (
                    dest_folder
                    if rel_sub == "."
                    else os.path.join(dest_folder, rel_sub)
                )
                print(f"DEBUG:       Traversing {rel_sub or '/'} → will copy into {os.path.relpath(target_root, output_dir)}")
                os.makedirs(target_root, exist_ok=True)

                for fname in files:
                    src_file = os.path.join(root, fname)
                    dest_file = os.path.join(target_root, fname)
                    print(f"DEBUG:         Copying {os.path.relpath(src_file, input_dir)} → {os.path.relpath(dest_file, output_dir)} ", end="")
                    try:
                        shutil.copy2(src_file, dest_file)
                        print("✔")
                    except Exception as e:
                        print(f"✘ ERROR: {e}")

            print(f"DEBUG:     Recursing into {rel_src}\n")
            group_yaml_by_source(src_folder, dest_folder)


if __name__ == "__main__":
    group_yaml_by_source(yaml_exec_source, yaml_exec_tree)
# Out:
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons
# DEBUG: └─ Found YAML file: aurora.tf.yaml
# DEBUG:     sources found in aurora.tf.yaml:
# DEBUG:       • module[0].aurora.source → '../modules/aurora'
#
# DEBUG:     Processing source: '../modules/aurora' (at module[0].aurora.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\aurora
# DEBUG:       Relative src_folder = ..\modules\aurora
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\aurora
# DEBUG:       Traversing . → will copy into modules\aurora
# DEBUG:         Copying ..\modules\aurora\data.tf.yaml → modules\aurora\data.tf.yaml ✔
# DEBUG:         Copying ..\modules\aurora\main.tf.yaml → modules\aurora\main.tf.yaml ✔
# DEBUG:         Copying ..\modules\aurora\output.tf.yaml → modules\aurora\output.tf.yaml ✔
# DEBUG:         Copying ..\modules\aurora\variables.tf.yaml → modules\aurora\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\modules\aurora
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\aurora
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\aurora
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\aurora
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     sources found in main.tf.yaml:
# DEBUG:       • module[0].secrets_manager.source → '../secrets_manager'
#
# DEBUG:     Processing source: '../secrets_manager' (at module[0].secrets_manager.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG:       Relative src_folder = ..\secrets_manager
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\aurora\secrets_manager
# DEBUG:       Traversing . → will copy into secrets_manager
# DEBUG:         Copying ..\secrets_manager\data.tf.yaml → secrets_manager\data.tf.yaml ✔
# DEBUG:         Copying ..\secrets_manager\main.tf.yaml → secrets_manager\main.tf.yaml ✔
# DEBUG:         Copying ..\secrets_manager\outputs.tf.yaml → secrets_manager\outputs.tf.yaml ✔
# DEBUG:         Copying ..\secrets_manager\variables.tf.yaml → secrets_manager\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\secrets_manager
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\aurora\secrets_manager
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     No 'source:' keys found in main.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: output.tf.yaml
# DEBUG:     No 'source:' keys found in output.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     sources found in cloud.tf.yaml:
# DEBUG:       • terraform[0].required_providers[0].aws.source → 'hashicorp/aws'
# DEBUG:       • terraform[0].required_providers[0].kubectl.source → 'gavinbunney/kubectl'
# DEBUG:       • module[0].cdis_vpc.source → '../modules/vpc'
# DEBUG:       • module[1].config_files.source → '../../shared/modules/k8s_configs'
# DEBUG:       • module[2].csoc_peering_connection.source → '../modules/csoc_peering'
#
# DEBUG:     Processing source: 'hashicorp/aws' (at terraform[0].required_providers[0].aws.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\hashicorp\aws
# DEBUG:       Relative src_folder = hashicorp\aws
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\hashicorp\aws
# DEBUG:       src_folder hashicorp\aws is not a directory; skipping copy.
#
# DEBUG:     Processing source: 'gavinbunney/kubectl' (at terraform[0].required_providers[0].kubectl.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\gavinbunney\kubectl
# DEBUG:       Relative src_folder = gavinbunney\kubectl
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gavinbunney\kubectl
# DEBUG:       src_folder gavinbunney\kubectl is not a directory; skipping copy.
#
# DEBUG:     Processing source: '../modules/vpc' (at module[0].cdis_vpc.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\vpc
# DEBUG:       Relative src_folder = ..\modules\vpc
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc
# DEBUG:       Traversing . → will copy into modules\vpc
# DEBUG:         Copying ..\modules\vpc\cloud.tf.yaml → modules\vpc\cloud.tf.yaml ✔
# DEBUG:         Copying ..\modules\vpc\data.tf.yaml → modules\vpc\data.tf.yaml ✔
# DEBUG:         Copying ..\modules\vpc\outputs.tf.yaml → modules\vpc\outputs.tf.yaml ✔
# DEBUG:         Copying ..\modules\vpc\README.md → modules\vpc\README.md ✔
# DEBUG:         Copying ..\modules\vpc\security-groups.tf.yaml → modules\vpc\security-groups.tf.yaml ✔
# DEBUG:         Copying ..\modules\vpc\variables.tf.yaml → modules\vpc\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\modules\vpc
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\vpc
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\vpc
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     sources found in cloud.tf.yaml:
# DEBUG:       • module[0].squid-auto.source → '../squid_auto'
# DEBUG:       • module[1].data-bucket.source → '../upload-data-bucket'
# DEBUG:       • module[2].fence-bot-user.source → '../fence-bot-user'
#
# DEBUG:     Processing source: '../squid_auto' (at module[0].squid-auto.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\squid_auto
# DEBUG:       Relative src_folder = ..\squid_auto
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\squid_auto
# DEBUG:       Traversing . → will copy into squid_auto
# DEBUG:         Copying ..\squid_auto\cloud.tf.yaml → squid_auto\cloud.tf.yaml ✔
# DEBUG:         Copying ..\squid_auto\data.tf.yaml → squid_auto\data.tf.yaml ✔
# DEBUG:         Copying ..\squid_auto\outputs.tf.yaml → squid_auto\outputs.tf.yaml ✔
# DEBUG:         Copying ..\squid_auto\README.md → squid_auto\README.md ✔
# DEBUG:         Copying ..\squid_auto\variables.tf.yaml → squid_auto\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\squid_auto
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\squid_auto
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\squid_auto
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\squid_auto
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../upload-data-bucket' (at module[1].data-bucket.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\upload-data-bucket
# DEBUG:       Relative src_folder = ..\upload-data-bucket
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\upload-data-bucket
# DEBUG:       Traversing . → will copy into upload-data-bucket
# DEBUG:         Copying ..\upload-data-bucket\data.tf.yaml → upload-data-bucket\data.tf.yaml ✔
# DEBUG:         Copying ..\upload-data-bucket\iam.tf.yaml → upload-data-bucket\iam.tf.yaml ✔
# DEBUG:         Copying ..\upload-data-bucket\main.tf.yaml → upload-data-bucket\main.tf.yaml ✔
# DEBUG:         Copying ..\upload-data-bucket\outputs.tf.yaml → upload-data-bucket\outputs.tf.yaml ✔
# DEBUG:         Copying ..\upload-data-bucket\README.md → upload-data-bucket\README.md ✔
# DEBUG:         Copying ..\upload-data-bucket\s3.tf.yaml → upload-data-bucket\s3.tf.yaml ✔
# DEBUG:         Copying ..\upload-data-bucket\variables.tf.yaml → upload-data-bucket\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\upload-data-bucket
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\upload-data-bucket
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\upload-data-bucket
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\upload-data-bucket
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: iam.tf.yaml
# DEBUG:     No 'source:' keys found in iam.tf.yaml
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     sources found in main.tf.yaml:
# DEBUG:       • module[0].data-bucket-queue.source → '../data-bucket-queue'
# DEBUG:       • module[1].cloud-trail.source → '../cloud-trail'
#
# DEBUG:     Processing source: '../data-bucket-queue' (at module[0].data-bucket-queue.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\data-bucket-queue
# DEBUG:       Relative src_folder = ..\data-bucket-queue
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\upload-data-bucket\data-bucket-queue
# DEBUG:       Traversing . → will copy into data-bucket-queue
# DEBUG:         Copying ..\data-bucket-queue\cloud.tf.yaml → data-bucket-queue\cloud.tf.yaml ✔
# DEBUG:         Copying ..\data-bucket-queue\data.tf.yaml → data-bucket-queue\data.tf.yaml ✔
# DEBUG:         Copying ..\data-bucket-queue\outputs.tf.yaml → data-bucket-queue\outputs.tf.yaml ✔
# DEBUG:         Copying ..\data-bucket-queue\README.md → data-bucket-queue\README.md ✔
# DEBUG:         Copying ..\data-bucket-queue\sample.tfvars → data-bucket-queue\sample.tfvars ✔
# DEBUG:         Copying ..\data-bucket-queue\variables.tf.yaml → data-bucket-queue\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\data-bucket-queue
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\data-bucket-queue
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\upload-data-bucket\data-bucket-queue
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\data-bucket-queue
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Skipping non-YAML (sample.tfvars)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../cloud-trail' (at module[1].cloud-trail.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\cloud-trail
# DEBUG:       Relative src_folder = ..\cloud-trail
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\upload-data-bucket\cloud-trail
# DEBUG:       Traversing . → will copy into cloud-trail
# DEBUG:         Copying ..\cloud-trail\data.tf.yaml → cloud-trail\data.tf.yaml ✔
# DEBUG:         Copying ..\cloud-trail\main.tf.yaml → cloud-trail\main.tf.yaml ✔
# DEBUG:         Copying ..\cloud-trail\variables.tf.yaml → cloud-trail\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\cloud-trail
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\cloud-trail
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\upload-data-bucket\cloud-trail
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\cloud-trail
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     No 'source:' keys found in main.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: s3.tf.yaml
# DEBUG:     No 'source:' keys found in s3.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../fence-bot-user' (at module[2].fence-bot-user.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\fence-bot-user
# DEBUG:       Relative src_folder = ..\fence-bot-user
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\fence-bot-user
# DEBUG:       Traversing . → will copy into fence-bot-user
# DEBUG:         Copying ..\fence-bot-user\data.tf.yaml → fence-bot-user\data.tf.yaml ✔
# DEBUG:         Copying ..\fence-bot-user\iam.tf.yaml → fence-bot-user\iam.tf.yaml ✔
# DEBUG:         Copying ..\fence-bot-user\output.tf.yaml → fence-bot-user\output.tf.yaml ✔
# DEBUG:         Copying ..\fence-bot-user\README.md → fence-bot-user\README.md ✔
# DEBUG:         Copying ..\fence-bot-user\variables.tf.yaml → fence-bot-user\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\fence-bot-user
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\fence-bot-user
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\vpc\fence-bot-user
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\fence-bot-user
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: iam.tf.yaml
# DEBUG:     No 'source:' keys found in iam.tf.yaml
# DEBUG: └─ Found YAML file: output.tf.yaml
# DEBUG:     No 'source:' keys found in output.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: security-groups.tf.yaml
# DEBUG:     No 'source:' keys found in security-groups.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../../shared/modules/k8s_configs' (at module[1].config_files.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs
# DEBUG:       Relative src_folder = ..\..\shared\modules\k8s_configs
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\shared\modules\k8s_configs
# DEBUG:       Traversing . → will copy into shared\modules\k8s_configs
# DEBUG:         Copying ..\..\shared\modules\k8s_configs\00configmap.yaml → shared\modules\k8s_configs\00configmap.yaml ✔
# DEBUG:         Copying ..\..\shared\modules\k8s_configs\creds.tpl → shared\modules\k8s_configs\creds.tpl ✔
# DEBUG:         Copying ..\..\shared\modules\k8s_configs\kube-vars.sh.tpl → shared\modules\k8s_configs\kube-vars.sh.tpl ✔
# DEBUG:         Copying ..\..\shared\modules\k8s_configs\outputs.tf.yaml → shared\modules\k8s_configs\outputs.tf.yaml ✔
# DEBUG:         Copying ..\..\shared\modules\k8s_configs\root.tf.yaml → shared\modules\k8s_configs\root.tf.yaml ✔
# DEBUG:         Copying ..\..\shared\modules\k8s_configs\variables.tf.yaml → shared\modules\k8s_configs\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\..\shared\modules\k8s_configs
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\shared\modules\k8s_configs
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\shared\modules\k8s_configs
# DEBUG: └─ Found YAML file: 00configmap.yaml
# DEBUG:     No 'source:' keys found in 00configmap.yaml
# DEBUG: └─ Skipping non-YAML (creds.tpl)
# DEBUG: └─ Skipping non-YAML (kube-vars.sh.tpl)
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Found YAML file: root.tf.yaml
# DEBUG:     No 'source:' keys found in root.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../modules/csoc_peering' (at module[2].csoc_peering_connection.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\csoc_peering
# DEBUG:       Relative src_folder = ..\modules\csoc_peering
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\csoc_peering
# DEBUG:       Traversing . → will copy into modules\csoc_peering
# DEBUG:         Copying ..\modules\csoc_peering\cloud.tf.yaml → modules\csoc_peering\cloud.tf.yaml ✔
# DEBUG:         Copying ..\modules\csoc_peering\data.tf.yaml → modules\csoc_peering\data.tf.yaml ✔
# DEBUG:         Copying ..\modules\csoc_peering\variables.tf.yaml → modules\csoc_peering\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\modules\csoc_peering
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\csoc_peering
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\csoc_peering
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\csoc_peering
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: cluster.yaml
# DEBUG:     No 'source:' keys found in cluster.yaml
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: eks.tf.yaml
# DEBUG:     sources found in eks.tf.yaml:
# DEBUG:       • module[0].eks.source → '../modules/eks'
#
# DEBUG:     Processing source: '../modules/eks' (at module[0].eks.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks
# DEBUG:       Relative src_folder = ..\modules\eks
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks
# DEBUG:       Traversing . → will copy into modules\eks
# DEBUG:         Copying ..\modules\eks\asg.tf.yaml → modules\eks\asg.tf.yaml ✔
# DEBUG:         Copying ..\modules\eks\cloud.tf.yaml → modules\eks\cloud.tf.yaml ✔
# DEBUG:         Copying ..\modules\eks\data.tf.yaml → modules\eks\data.tf.yaml ✔
# DEBUG:         Copying ..\modules\eks\endpoints.tf.yaml → modules\eks\endpoints.tf.yaml ✔
# DEBUG:         Copying ..\modules\eks\init_cluster.sh → modules\eks\init_cluster.sh ✔
# DEBUG:         Copying ..\modules\eks\karpenter.tf.yaml → modules\eks\karpenter.tf.yaml ✔
# DEBUG:         Copying ..\modules\eks\kubeconfig.tpl → modules\eks\kubeconfig.tpl ✔
# DEBUG:         Copying ..\modules\eks\lambda.tf.yaml → modules\eks\lambda.tf.yaml ✔
# DEBUG:         Copying ..\modules\eks\lambda_function.py → modules\eks\lambda_function.py ✔
# DEBUG:         Copying ..\modules\eks\outputs.tf.yaml → modules\eks\outputs.tf.yaml ✔
# DEBUG:         Copying ..\modules\eks\README.md → modules\eks\README.md ✔
# DEBUG:         Copying ..\modules\eks\variables.tf.yaml → modules\eks\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\modules\eks
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks
# DEBUG: └─ Found YAML file: asg.tf.yaml
# DEBUG:     No 'source:' keys found in asg.tf.yaml
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     sources found in cloud.tf.yaml:
# DEBUG:       • terraform[0].required_providers[0].kubectl.source → 'gavinbunney/kubectl'
# DEBUG:       • module[0].jupyter_pool.source → '../eks-nodepool/'
# DEBUG:       • module[1].workflow_pool.source → '../eks-nodepool/'
#
# DEBUG:     Processing source: 'gavinbunney/kubectl' (at terraform[0].required_providers[0].kubectl.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks\gavinbunney\kubectl
# DEBUG:       Relative src_folder = gavinbunney\kubectl
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks\gavinbunney\kubectl
# DEBUG:       src_folder gavinbunney\kubectl is not a directory; skipping copy.
#
# DEBUG:     Processing source: '../eks-nodepool/' (at module[0].jupyter_pool.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks-nodepool
# DEBUG:       Relative src_folder = ..\eks-nodepool
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks\eks-nodepool\
# DEBUG:       Traversing . → will copy into eks-nodepool
# DEBUG:         Copying ..\eks-nodepool\cloud.tf.yaml → eks-nodepool\cloud.tf.yaml ✔
# DEBUG:         Copying ..\eks-nodepool\data.tf.yaml → eks-nodepool\data.tf.yaml ✔
# DEBUG:         Copying ..\eks-nodepool\outputs.tf.yaml → eks-nodepool\outputs.tf.yaml ✔
# DEBUG:         Copying ..\eks-nodepool\README.md → eks-nodepool\README.md ✔
# DEBUG:         Copying ..\eks-nodepool\variables.tf.yaml → eks-nodepool\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\eks-nodepool
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks-nodepool
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks\eks-nodepool
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks-nodepool
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../eks-nodepool/' (at module[1].workflow_pool.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks-nodepool
# DEBUG:       Relative src_folder = ..\eks-nodepool
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks\eks-nodepool\
# DEBUG:       Traversing . → will copy into eks-nodepool
# DEBUG:         Copying ..\eks-nodepool\cloud.tf.yaml → eks-nodepool\cloud.tf.yaml ✔
# DEBUG:         Copying ..\eks-nodepool\data.tf.yaml → eks-nodepool\data.tf.yaml ✔
# DEBUG:         Copying ..\eks-nodepool\outputs.tf.yaml → eks-nodepool\outputs.tf.yaml ✔
# DEBUG:         Copying ..\eks-nodepool\README.md → eks-nodepool\README.md ✔
# DEBUG:         Copying ..\eks-nodepool\variables.tf.yaml → eks-nodepool\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\eks-nodepool
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks-nodepool
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks\eks-nodepool
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\eks-nodepool
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: endpoints.tf.yaml
# DEBUG:     No 'source:' keys found in endpoints.tf.yaml
# DEBUG: └─ Skipping non-YAML (init_cluster.sh)
# DEBUG: └─ Found YAML file: karpenter.tf.yaml
# DEBUG:     No 'source:' keys found in karpenter.tf.yaml
# DEBUG: └─ Skipping non-YAML (kubeconfig.tpl)
# DEBUG: └─ Found YAML file: lambda.tf.yaml
# DEBUG:     sources found in lambda.tf.yaml:
# DEBUG:       • module[0].iam_role.source → '../iam-role'
# DEBUG:       • module[1].iam_policy.source → '../iam-policy'
#
# DEBUG:     Processing source: '../iam-role' (at module[0].iam_role.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\iam-role
# DEBUG:       Relative src_folder = ..\iam-role
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks\iam-role
# DEBUG:       Traversing . → will copy into iam-role
# DEBUG:         Copying ..\iam-role\main.tf.yaml → iam-role\main.tf.yaml ✔
# DEBUG:         Copying ..\iam-role\output.tf.yaml → iam-role\output.tf.yaml ✔
# DEBUG:         Copying ..\iam-role\README.md → iam-role\README.md ✔
# DEBUG:         Copying ..\iam-role\variables.tf.yaml → iam-role\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\iam-role
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\iam-role
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks\iam-role
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\iam-role
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     No 'source:' keys found in main.tf.yaml
# DEBUG: └─ Found YAML file: output.tf.yaml
# DEBUG:     No 'source:' keys found in output.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../iam-policy' (at module[1].iam_policy.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\iam-policy
# DEBUG:       Relative src_folder = ..\iam-policy
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks\iam-policy
# DEBUG:       Traversing . → will copy into iam-policy
# DEBUG:         Copying ..\iam-policy\main.tf.yaml → iam-policy\main.tf.yaml ✔
# DEBUG:         Copying ..\iam-policy\output.tf.yaml → iam-policy\output.tf.yaml ✔
# DEBUG:         Copying ..\iam-policy\README.md → iam-policy\README.md ✔
# DEBUG:         Copying ..\iam-policy\variables.tf.yaml → iam-policy\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\iam-policy
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\iam-policy
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\eks\iam-policy
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\iam-policy
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     No 'source:' keys found in main.tf.yaml
# DEBUG: └─ Found YAML file: output.tf.yaml
# DEBUG:     No 'source:' keys found in output.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Skipping non-YAML (lambda_function.py)
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: es.tf.yaml
# DEBUG:     sources found in es.tf.yaml:
# DEBUG:       • module[0].commons_vpc_es.source → '../modules/commons-vpc-es'
#
# DEBUG:     Processing source: '../modules/commons-vpc-es' (at module[0].commons_vpc_es.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\commons-vpc-es
# DEBUG:       Relative src_folder = ..\modules\commons-vpc-es
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\commons-vpc-es
# DEBUG:       Traversing . → will copy into modules\commons-vpc-es
# DEBUG:         Copying ..\modules\commons-vpc-es\cloud.tf.yaml → modules\commons-vpc-es\cloud.tf.yaml ✔
# DEBUG:         Copying ..\modules\commons-vpc-es\data.tf.yaml → modules\commons-vpc-es\data.tf.yaml ✔
# DEBUG:         Copying ..\modules\commons-vpc-es\outputs.tf.yaml → modules\commons-vpc-es\outputs.tf.yaml ✔
# DEBUG:         Copying ..\modules\commons-vpc-es\README.md → modules\commons-vpc-es\README.md ✔
# DEBUG:         Copying ..\modules\commons-vpc-es\variables.tf.yaml → modules\commons-vpc-es\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\modules\commons-vpc-es
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\commons-vpc-es
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\commons-vpc-es
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\commons-vpc-es
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: helm.tf.yaml
# DEBUG:     sources found in helm.tf.yaml:
# DEBUG:       • module[0].gen3_deployment.source → '../../gen3'
#
# DEBUG:     Processing source: '../../gen3' (at module[0].gen3_deployment.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG:       Relative src_folder = ..\..\gen3
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3
# DEBUG:       Traversing . → will copy into gen3
# DEBUG:         Copying ..\..\gen3\aws-user-creds.tftpl → gen3\aws-user-creds.tftpl ✔
# DEBUG:         Copying ..\..\gen3\data.tf.yaml → gen3\data.tf.yaml ✔
# DEBUG:         Copying ..\..\gen3\db.tf.yaml → gen3\db.tf.yaml ✔
# DEBUG:         Copying ..\..\gen3\fence-config.tftpl → gen3\fence-config.tftpl ✔
# DEBUG:         Copying ..\..\gen3\root.tf.yaml → gen3\root.tf.yaml ✔
# DEBUG:         Copying ..\..\gen3\s3.tf.yaml → gen3\s3.tf.yaml ✔
# DEBUG:         Copying ..\..\gen3\secrets.tf.yaml → gen3\secrets.tf.yaml ✔
# DEBUG:         Copying ..\..\gen3\service-accounts.tf.yaml → gen3\service-accounts.tf.yaml ✔
# DEBUG:         Copying ..\..\gen3\sqs.tf.yaml → gen3\sqs.tf.yaml ✔
# DEBUG:         Copying ..\..\gen3\values.tftpl → gen3\values.tftpl ✔
# DEBUG:         Copying ..\..\gen3\variables.tf.yaml → gen3\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\..\gen3
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\gen3
# DEBUG: └─ Skipping non-YAML (aws-user-creds.tftpl)
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: db.tf.yaml
# DEBUG:     sources found in db.tf.yaml:
# DEBUG:       • module[0].arborist-db.source → '../aws/aurora_db'
# DEBUG:       • module[1].argo-db.source → '../aws/aurora_db'
# DEBUG:       • module[2].audit-db.source → '../aws/aurora_db'
# DEBUG:       • module[3].dicom-viewer-db.source → '../aws/aurora_db'
# DEBUG:       • module[4].dicom-server-db.source → '../aws/aurora_db'
# DEBUG:       • module[5].fence-db.source → '../aws/aurora_db'
# DEBUG:       • module[6].indexd-db.source → '../aws/aurora_db'
# DEBUG:       • module[7].metadata-db.source → '../aws/aurora_db'
# DEBUG:       • module[8].requestor-db.source → '../aws/aurora_db'
# DEBUG:       • module[9].sheepdog-db.source → '../aws/aurora_db'
# DEBUG:       • module[10].wts-db.source → '../aws/aurora_db'
#
# DEBUG:     Processing source: '../aws/aurora_db' (at module[0].arborist-db.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG:       Relative src_folder = ..\aws\aurora_db
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db
# DEBUG:       Traversing . → will copy into aws\aurora_db
# DEBUG:         Copying ..\aws\aurora_db\data.tf.yaml → aws\aurora_db\data.tf.yaml ✔
# DEBUG:         Copying ..\aws\aurora_db\db_setup.tftpl → aws\aurora_db\db_setup.tftpl ✔
# DEBUG:         Copying ..\aws\aurora_db\manifest.json → aws\aurora_db\manifest.json ✔
# DEBUG:         Copying ..\aws\aurora_db\root.tf.yaml → aws\aurora_db\root.tf.yaml ✔
# DEBUG:         Copying ..\aws\aurora_db\secrets_manager.tftpl → aws\aurora_db\secrets_manager.tftpl ✔
# DEBUG:         Copying ..\aws\aurora_db\variables.tf.yaml → aws\aurora_db\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\aws\aurora_db
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Skipping non-YAML (db_setup.tftpl)
# DEBUG: └─ Skipping non-YAML (manifest.json)
# DEBUG: └─ Found YAML file: root.tf.yaml
# DEBUG:     sources found in root.tf.yaml:
# DEBUG:       • module[0].secrets_manager.source → '../modules/secrets_manager'
#
# DEBUG:     Processing source: '../modules/secrets_manager' (at module[0].secrets_manager.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG:       Relative src_folder = ..\modules\secrets_manager
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db\modules\secrets_manager
# DEBUG:       Traversing . → will copy into modules\secrets_manager
# DEBUG:         Copying ..\modules\secrets_manager\data.tf.yaml → modules\secrets_manager\data.tf.yaml ✔
# DEBUG:         Copying ..\modules\secrets_manager\main.tf.yaml → modules\secrets_manager\main.tf.yaml ✔
# DEBUG:         Copying ..\modules\secrets_manager\outputs.tf.yaml → modules\secrets_manager\outputs.tf.yaml ✔
# DEBUG:         Copying ..\modules\secrets_manager\variables.tf.yaml → modules\secrets_manager\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\modules\secrets_manager
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db\modules\secrets_manager
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     No 'source:' keys found in main.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Skipping non-YAML (secrets_manager.tftpl)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../aws/aurora_db' (at module[1].argo-db.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG:       Relative src_folder = ..\aws\aurora_db
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db
# DEBUG:       Traversing . → will copy into aws\aurora_db
# DEBUG:         Copying ..\aws\aurora_db\data.tf.yaml → aws\aurora_db\data.tf.yaml ✔
# DEBUG:         Copying ..\aws\aurora_db\db_setup.tftpl → aws\aurora_db\db_setup.tftpl ✔
# DEBUG:         Copying ..\aws\aurora_db\manifest.json → aws\aurora_db\manifest.json ✔
# DEBUG:         Copying ..\aws\aurora_db\root.tf.yaml → aws\aurora_db\root.tf.yaml ✔
# DEBUG:         Copying ..\aws\aurora_db\secrets_manager.tftpl → aws\aurora_db\secrets_manager.tftpl ✔
# DEBUG:         Copying ..\aws\aurora_db\variables.tf.yaml → aws\aurora_db\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\aws\aurora_db
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Skipping non-YAML (db_setup.tftpl)
# DEBUG: └─ Skipping non-YAML (manifest.json)
# DEBUG: └─ Found YAML file: root.tf.yaml
# DEBUG:     sources found in root.tf.yaml:
# DEBUG:       • module[0].secrets_manager.source → '../modules/secrets_manager'
#
# DEBUG:     Processing source: '../modules/secrets_manager' (at module[0].secrets_manager.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG:       Relative src_folder = ..\modules\secrets_manager
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db\modules\secrets_manager
# DEBUG:       Traversing . → will copy into modules\secrets_manager
# DEBUG:         Copying ..\modules\secrets_manager\data.tf.yaml → modules\secrets_manager\data.tf.yaml ✔
# DEBUG:         Copying ..\modules\secrets_manager\main.tf.yaml → modules\secrets_manager\main.tf.yaml ✔
# DEBUG:         Copying ..\modules\secrets_manager\outputs.tf.yaml → modules\secrets_manager\outputs.tf.yaml ✔
# DEBUG:         Copying ..\modules\secrets_manager\variables.tf.yaml → modules\secrets_manager\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\modules\secrets_manager
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db\modules\secrets_manager
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     No 'source:' keys found in main.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Skipping non-YAML (secrets_manager.tftpl)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../aws/aurora_db' (at module[2].audit-db.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG:       Relative src_folder = ..\aws\aurora_db
# ...
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db\modules\secrets_manager
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     No 'source:' keys found in main.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Skipping non-YAML (secrets_manager.tftpl)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../aws/aurora_db' (at module[10].wts-db.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG:       Relative src_folder = ..\aws\aurora_db
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db
# DEBUG:       Traversing . → will copy into aws\aurora_db
# DEBUG:         Copying ..\aws\aurora_db\data.tf.yaml → aws\aurora_db\data.tf.yaml ✔
# DEBUG:         Copying ..\aws\aurora_db\db_setup.tftpl → aws\aurora_db\db_setup.tftpl ✔
# DEBUG:         Copying ..\aws\aurora_db\manifest.json → aws\aurora_db\manifest.json ✔
# DEBUG:         Copying ..\aws\aurora_db\root.tf.yaml → aws\aurora_db\root.tf.yaml ✔
# DEBUG:         Copying ..\aws\aurora_db\secrets_manager.tftpl → aws\aurora_db\secrets_manager.tftpl ✔
# DEBUG:         Copying ..\aws\aurora_db\variables.tf.yaml → aws\aurora_db\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\aws\aurora_db
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\aurora_db
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Skipping non-YAML (db_setup.tftpl)
# DEBUG: └─ Skipping non-YAML (manifest.json)
# DEBUG: └─ Found YAML file: root.tf.yaml
# DEBUG:     sources found in root.tf.yaml:
# DEBUG:       • module[0].secrets_manager.source → '../modules/secrets_manager'
#
# DEBUG:     Processing source: '../modules/secrets_manager' (at module[0].secrets_manager.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG:       Relative src_folder = ..\modules\secrets_manager
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db\modules\secrets_manager
# DEBUG:       Traversing . → will copy into modules\secrets_manager
# DEBUG:         Copying ..\modules\secrets_manager\data.tf.yaml → modules\secrets_manager\data.tf.yaml ✔
# DEBUG:         Copying ..\modules\secrets_manager\main.tf.yaml → modules\secrets_manager\main.tf.yaml ✔
# DEBUG:         Copying ..\modules\secrets_manager\outputs.tf.yaml → modules\secrets_manager\outputs.tf.yaml ✔
# DEBUG:         Copying ..\modules\secrets_manager\variables.tf.yaml → modules\secrets_manager\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\modules\secrets_manager
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\aurora_db\modules\secrets_manager
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\secrets_manager
# DEBUG: └─ Found YAML file: data.tf.yaml
# DEBUG:     No 'source:' keys found in data.tf.yaml
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     No 'source:' keys found in main.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Skipping non-YAML (secrets_manager.tftpl)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Skipping non-YAML (fence-config.tftpl)
# DEBUG: └─ Found YAML file: root.tf.yaml
# DEBUG:     No 'source:' keys found in root.tf.yaml
# DEBUG: └─ Found YAML file: s3.tf.yaml
# DEBUG:     sources found in s3.tf.yaml:
# DEBUG:       • module[0].manifest-s3-bucket.source → '../aws/modules/generic-bucket'
# DEBUG:       • module[1].grafana-s3-bucket.source → '../aws/modules/generic-bucket'
#
# DEBUG:     Processing source: '../aws/modules/generic-bucket' (at module[0].manifest-s3-bucket.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\generic-bucket
# DEBUG:       Relative src_folder = ..\aws\modules\generic-bucket
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\modules\generic-bucket
# DEBUG:       Traversing . → will copy into aws\modules\generic-bucket
# DEBUG:         Copying ..\aws\modules\generic-bucket\cloud.tf.yaml → aws\modules\generic-bucket\cloud.tf.yaml ✔
# DEBUG:         Copying ..\aws\modules\generic-bucket\variables.tf.yaml → aws\modules\generic-bucket\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\aws\modules\generic-bucket
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\generic-bucket
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\modules\generic-bucket
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\generic-bucket
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../aws/modules/generic-bucket' (at module[1].grafana-s3-bucket.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\generic-bucket
# DEBUG:       Relative src_folder = ..\aws\modules\generic-bucket
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\modules\generic-bucket
# DEBUG:       Traversing . → will copy into aws\modules\generic-bucket
# DEBUG:         Copying ..\aws\modules\generic-bucket\cloud.tf.yaml → aws\modules\generic-bucket\cloud.tf.yaml ✔
# DEBUG:         Copying ..\aws\modules\generic-bucket\variables.tf.yaml → aws\modules\generic-bucket\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\aws\modules\generic-bucket
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\generic-bucket
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\modules\generic-bucket
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\generic-bucket
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: secrets.tf.yaml
# DEBUG:     No 'source:' keys found in secrets.tf.yaml
# DEBUG: └─ Found YAML file: service-accounts.tf.yaml
# DEBUG:     No 'source:' keys found in service-accounts.tf.yaml
# DEBUG: └─ Found YAML file: sqs.tf.yaml
# DEBUG:     sources found in sqs.tf.yaml:
# DEBUG:       • module[0].audit-sqs.source → '../aws/modules/sqs'
# DEBUG:       • module[1].ssjdispatcher-sqs.source → '../aws/modules/sqs'
#
# DEBUG:     Processing source: '../aws/modules/sqs' (at module[0].audit-sqs.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\sqs
# DEBUG:       Relative src_folder = ..\aws\modules\sqs
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\modules\sqs
# DEBUG:       Traversing . → will copy into aws\modules\sqs
# DEBUG:         Copying ..\aws\modules\sqs\cloud.tf.yaml → aws\modules\sqs\cloud.tf.yaml ✔
# DEBUG:         Copying ..\aws\modules\sqs\outputs.tf.yaml → aws\modules\sqs\outputs.tf.yaml ✔
# DEBUG:         Copying ..\aws\modules\sqs\README.md → aws\modules\sqs\README.md ✔
# DEBUG:         Copying ..\aws\modules\sqs\variables.tf.yaml → aws\modules\sqs\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\aws\modules\sqs
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\sqs
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\modules\sqs
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\sqs
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
#
# DEBUG:     Processing source: '../aws/modules/sqs' (at module[1].ssjdispatcher-sqs.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\sqs
# DEBUG:       Relative src_folder = ..\aws\modules\sqs
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\modules\sqs
# DEBUG:       Traversing . → will copy into aws\modules\sqs
# DEBUG:         Copying ..\aws\modules\sqs\cloud.tf.yaml → aws\modules\sqs\cloud.tf.yaml ✔
# DEBUG:         Copying ..\aws\modules\sqs\outputs.tf.yaml → aws\modules\sqs\outputs.tf.yaml ✔
# DEBUG:         Copying ..\aws\modules\sqs\README.md → aws\modules\sqs\README.md ✔
# DEBUG:         Copying ..\aws\modules\sqs\variables.tf.yaml → aws\modules\sqs\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\aws\modules\sqs
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\sqs
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gen3\aws\modules\sqs
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\sqs
# DEBUG: └─ Found YAML file: cloud.tf.yaml
# DEBUG:     No 'source:' keys found in cloud.tf.yaml
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Skipping non-YAML (values.tftpl)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Skipping non-YAML (kube-up-body.sh)
# DEBUG: └─ Found YAML file: kube.tf.yaml
# DEBUG:     No 'source:' keys found in kube.tf.yaml
# DEBUG: └─ Skipping non-YAML (manifest.json)
# DEBUG: └─ Found YAML file: outputs.tf.yaml
# DEBUG:     No 'source:' keys found in outputs.tf.yaml
# DEBUG: └─ Found YAML file: passwords.tf.yaml
# DEBUG:     No 'source:' keys found in passwords.tf.yaml
# DEBUG: └─ Found YAML file: provider.tf.yaml
# DEBUG:     sources found in provider.tf.yaml:
# DEBUG:       • terraform[0].required_providers[0].kubectl.source → 'gavinbunney/kubectl'
#
# DEBUG:     Processing source: 'gavinbunney/kubectl' (at terraform[0].required_providers[0].kubectl.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\commons\gavinbunney\kubectl
# DEBUG:       Relative src_folder = gavinbunney\kubectl
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\gavinbunney\kubectl
# DEBUG:       src_folder gavinbunney\kubectl is not a directory; skipping copy.
# DEBUG: └─ Skipping non-YAML (README.md)
# DEBUG: └─ Skipping non-YAML (sample.tfvars)
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml
# DEBUG: └─ Found YAML file: waf.tf.yaml
# DEBUG:     sources found in waf.tf.yaml:
# DEBUG:       • module[0].aws_waf.source → '../modules/waf'
#
# DEBUG:     Processing source: '../modules/waf' (at module[0].aws_waf.source)
# DEBUG:       Absolute src_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\waf
# DEBUG:       Relative src_folder = ..\modules\waf
# DEBUG:       Computed dest_folder = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\waf
# DEBUG:       Traversing . → will copy into modules\waf
# DEBUG:         Copying ..\modules\waf\main.tf.yaml → modules\waf\main.tf.yaml ✔
# DEBUG:         Copying ..\modules\waf\output.tf.yaml → modules\waf\output.tf.yaml ✔
# DEBUG:         Copying ..\modules\waf\variables.tf.yaml → modules\waf\variables.tf.yaml ✔
# DEBUG:     Recursing into ..\modules\waf
#
# DEBUG: Normalized input_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\waf
# DEBUG: Normalized output_dir = c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_tree\modules\waf
#
# DEBUG: Scanning directory: c:\Users\boadeyem\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\Gen3\yaml_files\aws\modules\waf
# DEBUG: └─ Found YAML file: main.tf.yaml
# DEBUG:     No 'source:' keys found in main.tf.yaml
# DEBUG: └─ Found YAML file: output.tf.yaml
# DEBUG:     No 'source:' keys found in output.tf.yaml
# DEBUG: └─ Found YAML file: variables.tf.yaml
# DEBUG:     No 'source:' keys found in variables.tf.yaml

# %%
import shutil

# dirs_exist_ok=True (Python 3.8+) lets dst already exist
shutil.copytree(yaml_exec_source, yaml_exec_tree, dirs_exist_ok=True)
# Out:
# 'yaml_tree'
