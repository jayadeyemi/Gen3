# %% [markdown]
# Copy all non terraform files in directory

# %%
#!/usr/bin/env python3
"""
copy_non_tf.py

Copies all files under SOURCE_DIR that do NOT end with .tf
to DEST_DIR, preserving the directory structure.
"""

import os
import shutil
import sys

def copy_non_tf(source_dir, dest_dir):
    source_dir = os.path.abspath(source_dir)
    for root, _, files in os.walk(source_dir):
        # Compute relative path from the source root
        rel_dir = os.path.relpath(root, source_dir)
        for fname in files:
            if not fname.endswith('.tf'):
                src_path = os.path.join(root, fname)
                # Build the corresponding destination path
                target_dir = os.path.join(dest_dir, rel_dir)
                os.makedirs(target_dir, exist_ok=True)
                dst_path = os.path.join(target_dir, fname)
                shutil.copy2(src_path, dst_path)
                print(f"Copied: {src_path} → {dst_path}")

copy_non_tf("gen3-terraform-master/tf_files", "gen3-terraform-master/yaml_files")
# Out:
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\README.md → gen3-terraform-master/yaml_files\.\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\access\manifest.json → gen3-terraform-master/yaml_files\aws\access\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\access\sample.tfvars → gen3-terraform-master/yaml_files\aws\access\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\manifest.json → gen3-terraform-master/yaml_files\aws\account-policies\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\README.md → gen3-terraform-master/yaml_files\aws\account-policies\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\sample.tfvars → gen3-terraform-master/yaml_files\aws\account-policies\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\Cloud_Logging.json → gen3-terraform-master/yaml_files\aws\account-policies\custom_iam_policies\Cloud_Logging.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\Config_Read_List.json → gen3-terraform-master/yaml_files\aws\account-policies\custom_iam_policies\Config_Read_List.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\CtdsKmsSuper.json → gen3-terraform-master/yaml_files\aws\account-policies\custom_iam_policies\CtdsKmsSuper.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\DevOPSConsolidatedPolicies.json → gen3-terraform-master/yaml_files\aws\account-policies\custom_iam_policies\DevOPSConsolidatedPolicies.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\DevOpsDirectorConsolidatedPolicies.json → gen3-terraform-master/yaml_files\aws\account-policies\custom_iam_policies\DevOpsDirectorConsolidatedPolicies.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\DevOpsTroubleShooting_CLIFunctions.json → gen3-terraform-master/yaml_files\aws\account-policies\custom_iam_policies\DevOpsTroubleShooting_CLIFunctions.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\IAMConsoleListings.json → gen3-terraform-master/yaml_files\aws\account-policies\custom_iam_policies\IAMConsoleListings.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\Logs_Read.json → gen3-terraform-master/yaml_files\aws\account-policies\custom_iam_policies\Logs_Read.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account-policies\metadata\saml-metadata.xml → gen3-terraform-master/yaml_files\aws\account-policies\metadata\saml-metadata.xml
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account_management-logs\manifest.json → gen3-terraform-master/yaml_files\aws\account_management-logs\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\account_management-logs\sample.tfvars → gen3-terraform-master/yaml_files\aws\account_management-logs\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\aurora\manifest.json → gen3-terraform-master/yaml_files\aws\aurora\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\aurora_db\db_setup.tftpl → gen3-terraform-master/yaml_files\aws\aurora_db\db_setup.tftpl
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\aurora_db\manifest.json → gen3-terraform-master/yaml_files\aws\aurora_db\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\aurora_db\secrets_manager.tftpl → gen3-terraform-master/yaml_files\aws\aurora_db\secrets_manager.tftpl
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\batch\manifest.json → gen3-terraform-master/yaml_files\aws\batch\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\batch\sample.tfvars → gen3-terraform-master/yaml_files\aws\batch\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\bucket_manifest_utils\manifest.json → gen3-terraform-master/yaml_files\aws\bucket_manifest_utils\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\bucket_manifest_utils\sample.tfvars → gen3-terraform-master/yaml_files\aws\bucket_manifest_utils\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\cognito\manifest.json → gen3-terraform-master/yaml_files\aws\cognito\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\cognito\README.md → gen3-terraform-master/yaml_files\aws\cognito\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\cognito\sample.tfvars → gen3-terraform-master/yaml_files\aws\cognito\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\commons\cluster.yaml → gen3-terraform-master/yaml_files\aws\commons\cluster.yaml
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\commons\kube-up-body.sh → gen3-terraform-master/yaml_files\aws\commons\kube-up-body.sh
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\commons\manifest.json → gen3-terraform-master/yaml_files\aws\commons\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\commons\README.md → gen3-terraform-master/yaml_files\aws\commons\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\commons\sample.tfvars → gen3-terraform-master/yaml_files\aws\commons\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\commons_vpc_es\manifest.json → gen3-terraform-master/yaml_files\aws\commons_vpc_es\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\commons_vpc_es\sample.tfvars → gen3-terraform-master/yaml_files\aws\commons_vpc_es\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\csoc_admin_vm\manifest.json → gen3-terraform-master/yaml_files\aws\csoc_admin_vm\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\csoc_admin_vm\sample.tfvars → gen3-terraform-master/yaml_files\aws\csoc_admin_vm\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\csoc_common_logging\manifest.json → gen3-terraform-master/yaml_files\aws\csoc_common_logging\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\csoc_common_logging\sample.tfvars → gen3-terraform-master/yaml_files\aws\csoc_common_logging\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\csoc_management-logs\manifest.json → gen3-terraform-master/yaml_files\aws\csoc_management-logs\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\csoc_management-logs\sample.tfvars → gen3-terraform-master/yaml_files\aws\csoc_management-logs\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\datadog\manifest.json → gen3-terraform-master/yaml_files\aws\datadog\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\datadog\sample.tfvars → gen3-terraform-master/yaml_files\aws\datadog\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\datadog_api_monitor\manifest.json → gen3-terraform-master/yaml_files\aws\datadog_api_monitor\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\data_bucket\manifest.json → gen3-terraform-master/yaml_files\aws\data_bucket\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\data_bucket\README.md → gen3-terraform-master/yaml_files\aws\data_bucket\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\data_bucket\sample.tfvars → gen3-terraform-master/yaml_files\aws\data_bucket\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\data_bucket_queue\manifest.json → gen3-terraform-master/yaml_files\aws\data_bucket_queue\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\data_bucket_queue\sample.tfvars → gen3-terraform-master/yaml_files\aws\data_bucket_queue\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\db_reencrypt\manifest.json → gen3-terraform-master/yaml_files\aws\db_reencrypt\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\eks\manifest.json → gen3-terraform-master/yaml_files\aws\eks\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\eks\sample.tfvars → gen3-terraform-master/yaml_files\aws\eks\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\generic_commons\README.md → gen3-terraform-master/yaml_files\aws\generic_commons\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\account-management-logs\README.md → gen3-terraform-master/yaml_files\aws\modules\account-management-logs\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\admin-vm\README.md → gen3-terraform-master/yaml_files\aws\modules\admin-vm\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\common-logging\lambda_function.py → gen3-terraform-master/yaml_files\aws\modules\common-logging\lambda_function.py
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\common-logging\README.md → gen3-terraform-master/yaml_files\aws\modules\common-logging\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\common-logging\testLambda.py → gen3-terraform-master/yaml_files\aws\modules\common-logging\testLambda.py
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\common-logging\workflow.png → gen3-terraform-master/yaml_files\aws\modules\common-logging\workflow.png
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\common-logging\workflow.svg → gen3-terraform-master/yaml_files\aws\modules\common-logging\workflow.svg
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\commons-sns\README.md → gen3-terraform-master/yaml_files\aws\modules\commons-sns\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\commons-vpc-es\README.md → gen3-terraform-master/yaml_files\aws\modules\commons-vpc-es\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\data-bucket-queue\README.md → gen3-terraform-master/yaml_files\aws\modules\data-bucket-queue\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\data-bucket-queue\sample.tfvars → gen3-terraform-master/yaml_files\aws\modules\data-bucket-queue\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\eks\init_cluster.sh → gen3-terraform-master/yaml_files\aws\modules\eks\init_cluster.sh
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\eks\kubeconfig.tpl → gen3-terraform-master/yaml_files\aws\modules\eks\kubeconfig.tpl
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\eks\lambda_function.py → gen3-terraform-master/yaml_files\aws\modules\eks\lambda_function.py
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\eks\README.md → gen3-terraform-master/yaml_files\aws\modules\eks\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\eks-nodepool\README.md → gen3-terraform-master/yaml_files\aws\modules\eks-nodepool\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\fence-bot-user\README.md → gen3-terraform-master/yaml_files\aws\modules\fence-bot-user\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\iam-policy\README.md → gen3-terraform-master/yaml_files\aws\modules\iam-policy\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\iam-role\README.md → gen3-terraform-master/yaml_files\aws\modules\iam-role\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\lambda-function\README.md → gen3-terraform-master/yaml_files\aws\modules\lambda-function\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\management-logs\lambda_function.py → gen3-terraform-master/yaml_files\aws\modules\management-logs\lambda_function.py
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\management-logs\README.md → gen3-terraform-master/yaml_files\aws\modules\management-logs\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\management-logs\testLambda.py → gen3-terraform-master/yaml_files\aws\modules\management-logs\testLambda.py
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\management-logs\workflow.png → gen3-terraform-master/yaml_files\aws\modules\management-logs\workflow.png
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\rds\README.md → gen3-terraform-master/yaml_files\aws\modules\rds\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\s3-bucket\data-explorer.svg → gen3-terraform-master/yaml_files\aws\modules\s3-bucket\data-explorer.svg
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\s3-bucket\README.md → gen3-terraform-master/yaml_files\aws\modules\s3-bucket\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\s3-logs\README.md → gen3-terraform-master/yaml_files\aws\modules\s3-logs\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\sqs\README.md → gen3-terraform-master/yaml_files\aws\modules\sqs\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\squidnlb\README.md → gen3-terraform-master/yaml_files\aws\modules\squidnlb\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\squid_auto\README.md → gen3-terraform-master/yaml_files\aws\modules\squid_auto\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\squid_nlb_central_csoc\CSOC_Centralized_Squid_Set-up.svg → gen3-terraform-master/yaml_files\aws\modules\squid_nlb_central_csoc\CSOC_Centralized_Squid_Set-up.svg
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\squid_nlb_central_csoc\README.md → gen3-terraform-master/yaml_files\aws\modules\squid_nlb_central_csoc\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\upload-data-bucket\README.md → gen3-terraform-master/yaml_files\aws\modules\upload-data-bucket\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\utility-vm\README.md → gen3-terraform-master/yaml_files\aws\modules\utility-vm\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\vpc\README.md → gen3-terraform-master/yaml_files\aws\modules\vpc\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\vpn_nlb_central_csoc\README.md → gen3-terraform-master/yaml_files\aws\modules\vpn_nlb_central_csoc\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\modules\worker-bigdisk\README.md → gen3-terraform-master/yaml_files\aws\modules\worker-bigdisk\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\publicvm\manifest.json → gen3-terraform-master/yaml_files\aws\publicvm\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\publicvm\README.md → gen3-terraform-master/yaml_files\aws\publicvm\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\publicvm\sample.tfvars → gen3-terraform-master/yaml_files\aws\publicvm\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\rds\manifest.json → gen3-terraform-master/yaml_files\aws\rds\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\rds\sample.tfvars → gen3-terraform-master/yaml_files\aws\rds\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\role\manifest.json → gen3-terraform-master/yaml_files\aws\role\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\role\README.md → gen3-terraform-master/yaml_files\aws\role\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\role\sample.tfvars → gen3-terraform-master/yaml_files\aws\role\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\role_policy_attachment\manifest.json → gen3-terraform-master/yaml_files\aws\role_policy_attachment\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\role_policy_attachment\README.md → gen3-terraform-master/yaml_files\aws\role_policy_attachment\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\role_policy_attachment\sample.tfvars → gen3-terraform-master/yaml_files\aws\role_policy_attachment\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\secrets_manager\manifest.json → gen3-terraform-master/yaml_files\aws\secrets_manager\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\sftp\manifest.json → gen3-terraform-master/yaml_files\aws\sftp\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\sftp\sample.tfvars → gen3-terraform-master/yaml_files\aws\sftp\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\sqs\manifest.json → gen3-terraform-master/yaml_files\aws\sqs\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\sqs\sample.tfvars → gen3-terraform-master/yaml_files\aws\sqs\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\squidnlb_standalone\manifest.json → gen3-terraform-master/yaml_files\aws\squidnlb_standalone\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\squidnlb_standalone\sample.tfvars → gen3-terraform-master/yaml_files\aws\squidnlb_standalone\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\squid_auto\manifest.json → gen3-terraform-master/yaml_files\aws\squid_auto\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\squid_auto\sample.tfvars → gen3-terraform-master/yaml_files\aws\squid_auto\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\squid_nlb_central\manifest.json → gen3-terraform-master/yaml_files\aws\squid_nlb_central\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\squid_nlb_central\sample.tfvars → gen3-terraform-master/yaml_files\aws\squid_nlb_central\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\storage-gateway\manifest.json → gen3-terraform-master/yaml_files\aws\storage-gateway\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\storage-gateway\README.md → gen3-terraform-master/yaml_files\aws\storage-gateway\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\storage-gateway\sample.tfvars → gen3-terraform-master/yaml_files\aws\storage-gateway\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\user_generic\manifest.json → gen3-terraform-master/yaml_files\aws\user_generic\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\user_generic\README.md → gen3-terraform-master/yaml_files\aws\user_generic\README.md
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\user_generic\sample.tfvars → gen3-terraform-master/yaml_files\aws\user_generic\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\utility_vm\manifest.json → gen3-terraform-master/yaml_files\aws\utility_vm\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\utility_vm\sample.tfvars → gen3-terraform-master/yaml_files\aws\utility_vm\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\vpn_nlb_central\manifest.json → gen3-terraform-master/yaml_files\aws\vpn_nlb_central\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\vpn_nlb_central\sample.tfvars → gen3-terraform-master/yaml_files\aws\vpn_nlb_central\sample.tfvars
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\aws\waf\manifest.json → gen3-terraform-master/yaml_files\aws\waf\manifest.json
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\gen3\aws-user-creds.tftpl → gen3-terraform-master/yaml_files\gen3\aws-user-creds.tftpl
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\gen3\fence-config.tftpl → gen3-terraform-master/yaml_files\gen3\fence-config.tftpl
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\gen3\values.tftpl → gen3-terraform-master/yaml_files\gen3\values.tftpl
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\shared\modules\k8s_configs\00configmap.yaml → gen3-terraform-master/yaml_files\shared\modules\k8s_configs\00configmap.yaml
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\shared\modules\k8s_configs\creds.tpl → gen3-terraform-master/yaml_files\shared\modules\k8s_configs\creds.tpl
# Copied: c:\Users\babas\OneDrive - Indiana University\Documents\Masters-Career Documents\Portfolio\Projects\docker-learn\gen3-terraform-master\tf_files\shared\modules\k8s_configs\kube-vars.sh.tpl → gen3-terraform-master/yaml_files\shared\modules\k8s_configs\kube-vars.sh.tpl

# %% [markdown]
# Convert all terraform files and copy them to the destination directory

# %%
#!/usr/bin/env python3
"""
Recursively parse all .tf files in a directory and emit corresponding .tf.yaml files.
"""
import os
import argparse
import hcl2
import yaml

def parse_directory(src_dir: str, out_dir: str):
    for root, _, files in os.walk(src_dir):
        rel = os.path.relpath(root, src_dir)
        for fname in files:
            if not fname.endswith(".tf"):
                continue
            tf_path = os.path.join(root, fname)
            with open(tf_path, "r") as f:
                parsed = hcl2.load(f)
            # compute output path
            out_subdir = os.path.join(out_dir, rel) if rel != "." else out_dir
            os.makedirs(out_subdir, exist_ok=True)
            yaml_path = os.path.join(out_subdir, fname + ".yaml")
            with open(yaml_path, "w") as yf:
                yaml.safe_dump(parsed, yf, sort_keys=False)
            print(f"✓ {tf_path} → {yaml_path}")


parse_directory("gen3-terraform-master/tf_files/", "gen3-terraform-master/yaml_files/")
# Out:
# ✓ gen3-terraform-master/tf_files/aws\root.tf → gen3-terraform-master/yaml_files/aws\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\variables.tf → gen3-terraform-master/yaml_files/aws\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\access\cloud.tf → gen3-terraform-master/yaml_files/aws\access\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\access\variables.tf → gen3-terraform-master/yaml_files/aws\access\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\account-policies\ebs_encryption.tf → gen3-terraform-master/yaml_files/aws\account-policies\ebs_encryption.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\account-policies\iam_policies.tf → gen3-terraform-master/yaml_files/aws\account-policies\iam_policies.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\account-policies\identity_provider.tf → gen3-terraform-master/yaml_files/aws\account-policies\identity_provider.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\account-policies\main.tf → gen3-terraform-master/yaml_files/aws\account-policies\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\account-policies\s3_public_block.tf → gen3-terraform-master/yaml_files/aws\account-policies\s3_public_block.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\account-policies\variables.tf → gen3-terraform-master/yaml_files/aws\account-policies\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\account_management-logs\outputs.tf → gen3-terraform-master/yaml_files/aws\account_management-logs\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\account_management-logs\root.tf → gen3-terraform-master/yaml_files/aws\account_management-logs\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\account_management-logs\variables.tf → gen3-terraform-master/yaml_files/aws\account_management-logs\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\aurora\output.tf → gen3-terraform-master/yaml_files/aws\aurora\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\aurora\root.tf → gen3-terraform-master/yaml_files/aws\aurora\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\aurora\variables.tf → gen3-terraform-master/yaml_files/aws\aurora\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\aurora_db\data.tf → gen3-terraform-master/yaml_files/aws\aurora_db\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\aurora_db\root.tf → gen3-terraform-master/yaml_files/aws\aurora_db\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\aurora_db\variables.tf → gen3-terraform-master/yaml_files/aws\aurora_db\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\batch\root.tf → gen3-terraform-master/yaml_files/aws\batch\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\batch\variables.tf → gen3-terraform-master/yaml_files/aws\batch\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\bucket_manifest_utils\outputs.tf → gen3-terraform-master/yaml_files/aws\bucket_manifest_utils\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\bucket_manifest_utils\root.tf → gen3-terraform-master/yaml_files/aws\bucket_manifest_utils\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\bucket_manifest_utils\variables.tf → gen3-terraform-master/yaml_files/aws\bucket_manifest_utils\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\cognito\main.tf → gen3-terraform-master/yaml_files/aws\cognito\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\cognito\output.tf → gen3-terraform-master/yaml_files/aws\cognito\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\cognito\variables.tf → gen3-terraform-master/yaml_files/aws\cognito\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\aurora.tf → gen3-terraform-master/yaml_files/aws\commons\aurora.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\cloud.tf → gen3-terraform-master/yaml_files/aws\commons\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\data.tf → gen3-terraform-master/yaml_files/aws\commons\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\eks.tf → gen3-terraform-master/yaml_files/aws\commons\eks.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\es.tf → gen3-terraform-master/yaml_files/aws\commons\es.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\helm.tf → gen3-terraform-master/yaml_files/aws\commons\helm.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\kube.tf → gen3-terraform-master/yaml_files/aws\commons\kube.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\outputs.tf → gen3-terraform-master/yaml_files/aws\commons\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\passwords.tf → gen3-terraform-master/yaml_files/aws\commons\passwords.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\provider.tf → gen3-terraform-master/yaml_files/aws\commons\provider.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\variables.tf → gen3-terraform-master/yaml_files/aws\commons\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons\waf.tf → gen3-terraform-master/yaml_files/aws\commons\waf.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons_vpc_es\outputs.tf → gen3-terraform-master/yaml_files/aws\commons_vpc_es\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons_vpc_es\root.tf → gen3-terraform-master/yaml_files/aws\commons_vpc_es\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\commons_vpc_es\variables.tf → gen3-terraform-master/yaml_files/aws\commons_vpc_es\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\csoc_admin_vm\outputs.tf → gen3-terraform-master/yaml_files/aws\csoc_admin_vm\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\csoc_admin_vm\root.tf → gen3-terraform-master/yaml_files/aws\csoc_admin_vm\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\csoc_admin_vm\variables.tf → gen3-terraform-master/yaml_files/aws\csoc_admin_vm\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\csoc_common_logging\outputs.tf → gen3-terraform-master/yaml_files/aws\csoc_common_logging\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\csoc_common_logging\root.tf → gen3-terraform-master/yaml_files/aws\csoc_common_logging\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\csoc_common_logging\variables.tf → gen3-terraform-master/yaml_files/aws\csoc_common_logging\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\csoc_management-logs\outputs.tf → gen3-terraform-master/yaml_files/aws\csoc_management-logs\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\csoc_management-logs\root.tf → gen3-terraform-master/yaml_files/aws\csoc_management-logs\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\csoc_management-logs\variables.tf → gen3-terraform-master/yaml_files/aws\csoc_management-logs\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\datadog\cloud.tf → gen3-terraform-master/yaml_files/aws\datadog\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\datadog\variables.tf → gen3-terraform-master/yaml_files/aws\datadog\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\datadog_api_monitor\data.tf → gen3-terraform-master/yaml_files/aws\datadog_api_monitor\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\datadog_api_monitor\root.tf → gen3-terraform-master/yaml_files/aws\datadog_api_monitor\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\datadog_api_monitor\variables.tf → gen3-terraform-master/yaml_files/aws\datadog_api_monitor\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\datadog_api_monitor_jcoinprod\root.tf → gen3-terraform-master/yaml_files/aws\datadog_api_monitor_jcoinprod\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\datadog_api_monitor_jcoinprod\variables.tf → gen3-terraform-master/yaml_files/aws\datadog_api_monitor_jcoinprod\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\data_bucket\cloud.tf → gen3-terraform-master/yaml_files/aws\data_bucket\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\data_bucket\outputs.tf → gen3-terraform-master/yaml_files/aws\data_bucket\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\data_bucket\variables.tf → gen3-terraform-master/yaml_files/aws\data_bucket\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\data_bucket_queue\cloud.tf → gen3-terraform-master/yaml_files/aws\data_bucket_queue\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\data_bucket_queue\outputs.tf → gen3-terraform-master/yaml_files/aws\data_bucket_queue\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\data_bucket_queue\variables.tf → gen3-terraform-master/yaml_files/aws\data_bucket_queue\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\db_reencrypt\data.tf → gen3-terraform-master/yaml_files/aws\db_reencrypt\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\db_reencrypt\output.tf → gen3-terraform-master/yaml_files/aws\db_reencrypt\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\db_reencrypt\root.tf → gen3-terraform-master/yaml_files/aws\db_reencrypt\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\db_reencrypt\variables.tf → gen3-terraform-master/yaml_files/aws\db_reencrypt\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\eks\outputs.tf → gen3-terraform-master/yaml_files/aws\eks\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\eks\root.tf → gen3-terraform-master/yaml_files/aws\eks\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\eks\variables.tf → gen3-terraform-master/yaml_files/aws\eks\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\generic_bucket\root.tf → gen3-terraform-master/yaml_files/aws\generic_bucket\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\generic_bucket\variables.tf → gen3-terraform-master/yaml_files/aws\generic_bucket\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\generic_commons\data.tf → gen3-terraform-master/yaml_files/aws\generic_commons\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\generic_commons\root.tf → gen3-terraform-master/yaml_files/aws\generic_commons\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\generic_commons\variables.tf → gen3-terraform-master/yaml_files/aws\generic_commons\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\kms_key\outputs.tf → gen3-terraform-master/yaml_files/aws\kms_key\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\kms_key\root.tf → gen3-terraform-master/yaml_files/aws\kms_key\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\kms_key\variables.tf → gen3-terraform-master/yaml_files/aws\kms_key\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\account-management-logs\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\account-management-logs\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\account-management-logs\data.tf → gen3-terraform-master/yaml_files/aws\modules\account-management-logs\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\account-management-logs\event-alerts.tf → gen3-terraform-master/yaml_files/aws\modules\account-management-logs\event-alerts.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\account-management-logs\output.tf → gen3-terraform-master/yaml_files/aws\modules\account-management-logs\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\account-management-logs\variables.tf → gen3-terraform-master/yaml_files/aws\modules\account-management-logs\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\account-management-metrics\filters.tf → gen3-terraform-master/yaml_files/aws\modules\account-management-metrics\filters.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\account-management-metrics\metrics.tf → gen3-terraform-master/yaml_files/aws\modules\account-management-metrics\metrics.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\account-management-metrics\variables.tf → gen3-terraform-master/yaml_files/aws\modules\account-management-metrics\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\admin-vm\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\admin-vm\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\admin-vm\data.tf → gen3-terraform-master/yaml_files/aws\modules\admin-vm\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\admin-vm\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\admin-vm\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\admin-vm\variables.tf → gen3-terraform-master/yaml_files/aws\modules\admin-vm\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\aurora\data.tf → gen3-terraform-master/yaml_files/aws\modules\aurora\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\aurora\main.tf → gen3-terraform-master/yaml_files/aws\modules\aurora\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\aurora\output.tf → gen3-terraform-master/yaml_files/aws\modules\aurora\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\aurora\variables.tf → gen3-terraform-master/yaml_files/aws\modules\aurora\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\cloud-trail\data.tf → gen3-terraform-master/yaml_files/aws\modules\cloud-trail\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\cloud-trail\main.tf → gen3-terraform-master/yaml_files/aws\modules\cloud-trail\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\cloud-trail\variables.tf → gen3-terraform-master/yaml_files/aws\modules\cloud-trail\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\cloudwatch-events\main.tf → gen3-terraform-master/yaml_files/aws\modules\cloudwatch-events\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\cloudwatch-events\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\cloudwatch-events\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\cloudwatch-events\variables.tf → gen3-terraform-master/yaml_files/aws\modules\cloudwatch-events\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\common-logging\data.tf → gen3-terraform-master/yaml_files/aws\modules\common-logging\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\common-logging\logging.tf → gen3-terraform-master/yaml_files/aws\modules\common-logging\logging.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\common-logging\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\common-logging\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\common-logging\variables.tf → gen3-terraform-master/yaml_files/aws\modules\common-logging\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\commons-sns\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\commons-sns\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\commons-sns\data.tf → gen3-terraform-master/yaml_files/aws\modules\commons-sns\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\commons-sns\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\commons-sns\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\commons-sns\variables.tf → gen3-terraform-master/yaml_files/aws\modules\commons-sns\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\commons-vpc-es\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\commons-vpc-es\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\commons-vpc-es\data.tf → gen3-terraform-master/yaml_files/aws\modules\commons-vpc-es\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\commons-vpc-es\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\commons-vpc-es\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\commons-vpc-es\variables.tf → gen3-terraform-master/yaml_files/aws\modules\commons-vpc-es\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\csoc_peering\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\csoc_peering\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\csoc_peering\data.tf → gen3-terraform-master/yaml_files/aws\modules\csoc_peering\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\csoc_peering\variables.tf → gen3-terraform-master/yaml_files/aws\modules\csoc_peering\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\data-bucket-queue\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\data-bucket-queue\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\data-bucket-queue\data.tf → gen3-terraform-master/yaml_files/aws\modules\data-bucket-queue\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\data-bucket-queue\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\data-bucket-queue\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\data-bucket-queue\variables.tf → gen3-terraform-master/yaml_files/aws\modules\data-bucket-queue\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks\asg.tf → gen3-terraform-master/yaml_files/aws\modules\eks\asg.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\eks\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks\data.tf → gen3-terraform-master/yaml_files/aws\modules\eks\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks\endpoints.tf → gen3-terraform-master/yaml_files/aws\modules\eks\endpoints.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks\karpenter.tf → gen3-terraform-master/yaml_files/aws\modules\eks\karpenter.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks\lambda.tf → gen3-terraform-master/yaml_files/aws\modules\eks\lambda.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\eks\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks\variables.tf → gen3-terraform-master/yaml_files/aws\modules\eks\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks-nodepool\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\eks-nodepool\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks-nodepool\data.tf → gen3-terraform-master/yaml_files/aws\modules\eks-nodepool\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks-nodepool\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\eks-nodepool\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\eks-nodepool\variables.tf → gen3-terraform-master/yaml_files/aws\modules\eks-nodepool\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\fence-bot-user\data.tf → gen3-terraform-master/yaml_files/aws\modules\fence-bot-user\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\fence-bot-user\iam.tf → gen3-terraform-master/yaml_files/aws\modules\fence-bot-user\iam.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\fence-bot-user\output.tf → gen3-terraform-master/yaml_files/aws\modules\fence-bot-user\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\fence-bot-user\variables.tf → gen3-terraform-master/yaml_files/aws\modules\fence-bot-user\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\generic-bucket\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\generic-bucket\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\generic-bucket\variables.tf → gen3-terraform-master/yaml_files/aws\modules\generic-bucket\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\iam-policy\main.tf → gen3-terraform-master/yaml_files/aws\modules\iam-policy\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\iam-policy\output.tf → gen3-terraform-master/yaml_files/aws\modules\iam-policy\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\iam-policy\variables.tf → gen3-terraform-master/yaml_files/aws\modules\iam-policy\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\iam-role\main.tf → gen3-terraform-master/yaml_files/aws\modules\iam-role\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\iam-role\output.tf → gen3-terraform-master/yaml_files/aws\modules\iam-role\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\iam-role\variables.tf → gen3-terraform-master/yaml_files/aws\modules\iam-role\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\kms-key\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\kms-key\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\kms-key\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\kms-key\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\kms-key\variables.tf → gen3-terraform-master/yaml_files/aws\modules\kms-key\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\lambda-function\data.tf → gen3-terraform-master/yaml_files/aws\modules\lambda-function\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\lambda-function\main.tf → gen3-terraform-master/yaml_files/aws\modules\lambda-function\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\lambda-function\output.tf → gen3-terraform-master/yaml_files/aws\modules\lambda-function\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\lambda-function\variables.tf → gen3-terraform-master/yaml_files/aws\modules\lambda-function\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\management-logs\data.tf → gen3-terraform-master/yaml_files/aws\modules\management-logs\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\management-logs\logging.tf → gen3-terraform-master/yaml_files/aws\modules\management-logs\logging.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\management-logs\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\management-logs\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\management-logs\variables.tf → gen3-terraform-master/yaml_files/aws\modules\management-logs\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\rds\data.tf → gen3-terraform-master/yaml_files/aws\modules\rds\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\rds\main.tf → gen3-terraform-master/yaml_files/aws\modules\rds\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\rds\output.tf → gen3-terraform-master/yaml_files/aws\modules\rds\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\rds\variables.tf → gen3-terraform-master/yaml_files/aws\modules\rds\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\s3-bucket\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\s3-bucket\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\s3-bucket\data.tf → gen3-terraform-master/yaml_files/aws\modules\s3-bucket\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\s3-bucket\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\s3-bucket\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\s3-bucket\variables.tf → gen3-terraform-master/yaml_files/aws\modules\s3-bucket\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\s3-logs\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\s3-logs\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\s3-logs\data.tf → gen3-terraform-master/yaml_files/aws\modules\s3-logs\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\s3-logs\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\s3-logs\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\s3-logs\variables.tf → gen3-terraform-master/yaml_files/aws\modules\s3-logs\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\secrets_manager\data.tf → gen3-terraform-master/yaml_files/aws\modules\secrets_manager\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\secrets_manager\main.tf → gen3-terraform-master/yaml_files/aws\modules\secrets_manager\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\secrets_manager\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\secrets_manager\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\secrets_manager\variables.tf → gen3-terraform-master/yaml_files/aws\modules\secrets_manager\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\sqs\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\sqs\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\sqs\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\sqs\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\sqs\variables.tf → gen3-terraform-master/yaml_files/aws\modules\sqs\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squidnlb\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\squidnlb\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squidnlb\data.tf → gen3-terraform-master/yaml_files/aws\modules\squidnlb\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squidnlb\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\squidnlb\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squidnlb\variables.tf → gen3-terraform-master/yaml_files/aws\modules\squidnlb\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squid_auto\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\squid_auto\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squid_auto\data.tf → gen3-terraform-master/yaml_files/aws\modules\squid_auto\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squid_auto\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\squid_auto\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squid_auto\variables.tf → gen3-terraform-master/yaml_files/aws\modules\squid_auto\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squid_nlb_central_csoc\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\squid_nlb_central_csoc\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squid_nlb_central_csoc\data.tf → gen3-terraform-master/yaml_files/aws\modules\squid_nlb_central_csoc\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squid_nlb_central_csoc\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\squid_nlb_central_csoc\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\squid_nlb_central_csoc\variables.tf → gen3-terraform-master/yaml_files/aws\modules\squid_nlb_central_csoc\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\upload-data-bucket\data.tf → gen3-terraform-master/yaml_files/aws\modules\upload-data-bucket\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\upload-data-bucket\iam.tf → gen3-terraform-master/yaml_files/aws\modules\upload-data-bucket\iam.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\upload-data-bucket\main.tf → gen3-terraform-master/yaml_files/aws\modules\upload-data-bucket\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\upload-data-bucket\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\upload-data-bucket\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\upload-data-bucket\s3.tf → gen3-terraform-master/yaml_files/aws\modules\upload-data-bucket\s3.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\upload-data-bucket\variables.tf → gen3-terraform-master/yaml_files/aws\modules\upload-data-bucket\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\utility-vm\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\utility-vm\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\utility-vm\data.tf → gen3-terraform-master/yaml_files/aws\modules\utility-vm\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\utility-vm\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\utility-vm\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\utility-vm\variables.tf → gen3-terraform-master/yaml_files/aws\modules\utility-vm\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\vpc\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\vpc\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\vpc\data.tf → gen3-terraform-master/yaml_files/aws\modules\vpc\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\vpc\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\vpc\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\vpc\security-groups.tf → gen3-terraform-master/yaml_files/aws\modules\vpc\security-groups.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\vpc\variables.tf → gen3-terraform-master/yaml_files/aws\modules\vpc\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\vpn_nlb_central_csoc\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\vpn_nlb_central_csoc\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\vpn_nlb_central_csoc\data.tf → gen3-terraform-master/yaml_files/aws\modules\vpn_nlb_central_csoc\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\vpn_nlb_central_csoc\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\vpn_nlb_central_csoc\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\vpn_nlb_central_csoc\variables.tf → gen3-terraform-master/yaml_files/aws\modules\vpn_nlb_central_csoc\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\waf\main.tf → gen3-terraform-master/yaml_files/aws\modules\waf\main.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\waf\output.tf → gen3-terraform-master/yaml_files/aws\modules\waf\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\waf\variables.tf → gen3-terraform-master/yaml_files/aws\modules\waf\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\worker-bigdisk\cloud.tf → gen3-terraform-master/yaml_files/aws\modules\worker-bigdisk\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\worker-bigdisk\data.tf → gen3-terraform-master/yaml_files/aws\modules\worker-bigdisk\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\worker-bigdisk\outputs.tf → gen3-terraform-master/yaml_files/aws\modules\worker-bigdisk\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\modules\worker-bigdisk\variables.tf → gen3-terraform-master/yaml_files/aws\modules\worker-bigdisk\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\nextflow_ami_pipeline\data.tf → gen3-terraform-master/yaml_files/aws\nextflow_ami_pipeline\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\nextflow_ami_pipeline\iam.tf → gen3-terraform-master/yaml_files/aws\nextflow_ami_pipeline\iam.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\nextflow_ami_pipeline\imagebuilder.tf → gen3-terraform-master/yaml_files/aws\nextflow_ami_pipeline\imagebuilder.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\nextflow_ami_pipeline\root.tf → gen3-terraform-master/yaml_files/aws\nextflow_ami_pipeline\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\nextflow_ami_pipeline\variables.tf → gen3-terraform-master/yaml_files/aws\nextflow_ami_pipeline\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\opensearch-iam-role\data.tf → gen3-terraform-master/yaml_files/aws\opensearch-iam-role\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\opensearch-iam-role\root.tf → gen3-terraform-master/yaml_files/aws\opensearch-iam-role\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\opensearch-iam-role\variables.tf → gen3-terraform-master/yaml_files/aws\opensearch-iam-role\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\publicvm\data.tf → gen3-terraform-master/yaml_files/aws\publicvm\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\publicvm\outputs.tf → gen3-terraform-master/yaml_files/aws\publicvm\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\publicvm\root.tf → gen3-terraform-master/yaml_files/aws\publicvm\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\publicvm\variables.tf → gen3-terraform-master/yaml_files/aws\publicvm\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\rds\output.tf → gen3-terraform-master/yaml_files/aws\rds\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\rds\root.tf → gen3-terraform-master/yaml_files/aws\rds\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\rds\variables.tf → gen3-terraform-master/yaml_files/aws\rds\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\role\cloud.tf → gen3-terraform-master/yaml_files/aws\role\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\role\variables.tf → gen3-terraform-master/yaml_files/aws\role\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\role_policy_attachment\cloud.tf → gen3-terraform-master/yaml_files/aws\role_policy_attachment\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\role_policy_attachment\variables.tf → gen3-terraform-master/yaml_files/aws\role_policy_attachment\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\secrets_manager\outputs.tf → gen3-terraform-master/yaml_files/aws\secrets_manager\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\secrets_manager\root.tf → gen3-terraform-master/yaml_files/aws\secrets_manager\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\secrets_manager\variables.tf → gen3-terraform-master/yaml_files/aws\secrets_manager\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\sftp\cloud.tf → gen3-terraform-master/yaml_files/aws\sftp\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\sftp\output.tf → gen3-terraform-master/yaml_files/aws\sftp\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\sftp\variables.tf → gen3-terraform-master/yaml_files/aws\sftp\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\sqs\cloud.tf → gen3-terraform-master/yaml_files/aws\sqs\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\sqs\outputs.tf → gen3-terraform-master/yaml_files/aws\sqs\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\sqs\variables.tf → gen3-terraform-master/yaml_files/aws\sqs\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\squidnlb_standalone\outputs.tf → gen3-terraform-master/yaml_files/aws\squidnlb_standalone\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\squidnlb_standalone\root.tf → gen3-terraform-master/yaml_files/aws\squidnlb_standalone\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\squidnlb_standalone\variables.tf → gen3-terraform-master/yaml_files/aws\squidnlb_standalone\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\squid_auto\root.tf → gen3-terraform-master/yaml_files/aws\squid_auto\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\squid_auto\variables.tf → gen3-terraform-master/yaml_files/aws\squid_auto\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\squid_nlb_central\outputs.tf → gen3-terraform-master/yaml_files/aws\squid_nlb_central\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\squid_nlb_central\root.tf → gen3-terraform-master/yaml_files/aws\squid_nlb_central\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\squid_nlb_central\variables.tf → gen3-terraform-master/yaml_files/aws\squid_nlb_central\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\storage-gateway\cloud.tf → gen3-terraform-master/yaml_files/aws\storage-gateway\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\storage-gateway\data.tf → gen3-terraform-master/yaml_files/aws\storage-gateway\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\storage-gateway\variables.tf → gen3-terraform-master/yaml_files/aws\storage-gateway\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\user_generic\cloud.tf → gen3-terraform-master/yaml_files/aws\user_generic\cloud.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\user_generic\outputs.tf → gen3-terraform-master/yaml_files/aws\user_generic\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\user_generic\variables.tf → gen3-terraform-master/yaml_files/aws\user_generic\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\utility_vm\outputs.tf → gen3-terraform-master/yaml_files/aws\utility_vm\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\utility_vm\root.tf → gen3-terraform-master/yaml_files/aws\utility_vm\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\utility_vm\variables.tf → gen3-terraform-master/yaml_files/aws\utility_vm\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\vpn_nlb_central\outputs.tf → gen3-terraform-master/yaml_files/aws\vpn_nlb_central\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\vpn_nlb_central\root.tf → gen3-terraform-master/yaml_files/aws\vpn_nlb_central\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\vpn_nlb_central\variables.tf → gen3-terraform-master/yaml_files/aws\vpn_nlb_central\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\waf\output.tf → gen3-terraform-master/yaml_files/aws\waf\output.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\waf\root.tf → gen3-terraform-master/yaml_files/aws\waf\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/aws\waf\variables.tf → gen3-terraform-master/yaml_files/aws\waf\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/gen3\data.tf → gen3-terraform-master/yaml_files/gen3\data.tf.yaml
# ✓ gen3-terraform-master/tf_files/gen3\db.tf → gen3-terraform-master/yaml_files/gen3\db.tf.yaml
# ✓ gen3-terraform-master/tf_files/gen3\root.tf → gen3-terraform-master/yaml_files/gen3\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/gen3\s3.tf → gen3-terraform-master/yaml_files/gen3\s3.tf.yaml
# ✓ gen3-terraform-master/tf_files/gen3\secrets.tf → gen3-terraform-master/yaml_files/gen3\secrets.tf.yaml
# ✓ gen3-terraform-master/tf_files/gen3\service-accounts.tf → gen3-terraform-master/yaml_files/gen3\service-accounts.tf.yaml
# ✓ gen3-terraform-master/tf_files/gen3\sqs.tf → gen3-terraform-master/yaml_files/gen3\sqs.tf.yaml
# ✓ gen3-terraform-master/tf_files/gen3\variables.tf → gen3-terraform-master/yaml_files/gen3\variables.tf.yaml
# ✓ gen3-terraform-master/tf_files/shared\modules\k8s_configs\outputs.tf → gen3-terraform-master/yaml_files/shared\modules\k8s_configs\outputs.tf.yaml
# ✓ gen3-terraform-master/tf_files/shared\modules\k8s_configs\root.tf → gen3-terraform-master/yaml_files/shared\modules\k8s_configs\root.tf.yaml
# ✓ gen3-terraform-master/tf_files/shared\modules\k8s_configs\variables.tf → gen3-terraform-master/yaml_files/shared\modules\k8s_configs\variables.tf.yaml

# %% [markdown]
# Convert json to Yaml

# %%
# import os
# import json
# import yaml
# import glob

# def convert_all_json_to_yaml(directory: str = '.', output_dir: str = None):
#     if not os.path.isdir(directory):
#         raise FileNotFoundError(f"Directory not found: {directory!r}")

#     # Recursively find all .json files
#     pattern = os.path.join(directory, '**', '*.json')
#     files = glob.glob(pattern, recursive=True)
#     if not files:
#         print(f"No JSON files found in {directory!r}.")
#         return

#     for path in files:
#         size = os.path.getsize(path)
#         print(f"→ Processing {path} ({size} bytes)")
#         if size == 0:
#             print(f"  • Skipping empty file.")
#             continue

#         try:
#             with open(path, 'r', encoding='utf-8') as jf:
#                 data = json.load(jf)
#         except json.JSONDecodeError as e:
#             print(f"  ⚠️ Skipped invalid JSON: {e}")
#             continue

#         yaml_path = os.path.join(
#             output_dir if output_dir else os.path.dirname(path),
#             os.path.basename(path).replace('.json', '.yaml')
#         )
#         with open(yaml_path, 'w', encoding='utf-8') as yf:
#             yaml.dump(data, yf, default_flow_style=False)
#         print(f"  ✓ Wrote {yaml_path}")

# # — example invocation —
# convert_all_json_to_yaml("gen3-terraform-master", "gen3-terraform-master-yaml")
# Out:
# → Processing gen3-terraform-master\flavors\squid_auto\startup_configs\docker-daemon.json (62 bytes)
#   ✓ Wrote gen3-terraform-master\flavors\squid_auto\startup_configs\docker-daemon.yaml
# → Processing gen3-terraform-master\tf_files\aws\access\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\access\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\account-policies\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account-policies\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\Cloud_Logging.json (301 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\Cloud_Logging.yaml
# → Processing gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\Config_Read_List.json (1618 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\Config_Read_List.yaml
# → Processing gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\CtdsKmsSuper.json (204 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\CtdsKmsSuper.yaml
# → Processing gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\DevOPSConsolidatedPolicies.json (696 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\DevOPSConsolidatedPolicies.yaml
# → Processing gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\DevOpsDirectorConsolidatedPolicies.json (1830 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\DevOpsDirectorConsolidatedPolicies.yaml
# → Processing gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\DevOpsTroubleShooting_CLIFunctions.json (606 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\DevOpsTroubleShooting_CLIFunctions.yaml
# → Processing gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\IAMConsoleListings.json (734 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\IAMConsoleListings.yaml
# → Processing gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\Logs_Read.json (850 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account-policies\custom_iam_policies\Logs_Read.yaml
# → Processing gen3-terraform-master\tf_files\aws\account_management-logs\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\account_management-logs\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\aurora\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\aurora\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\aurora_db\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\aurora_db\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\batch\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\batch\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\bucket_manifest_utils\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\bucket_manifest_utils\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\cognito\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\cognito\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\commons\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\commons\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\commons_vpc_es\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\commons_vpc_es\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\csoc_admin_vm\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\csoc_admin_vm\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\csoc_common_logging\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\csoc_common_logging\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\csoc_management-logs\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\csoc_management-logs\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\datadog\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\datadog\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\datadog_api_monitor\manifest.json (54 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\datadog_api_monitor\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\data_bucket\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\data_bucket\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\data_bucket_queue\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\data_bucket_queue\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\db_reencrypt\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\db_reencrypt\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\eks\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\eks\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\publicvm\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\publicvm\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\rds\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\rds\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\role\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\role\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\role_policy_attachment\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\role_policy_attachment\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\secrets_manager\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\secrets_manager\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\sftp\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\sftp\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\sqs\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\sqs\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\squidnlb_standalone\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\squidnlb_standalone\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\squid_auto\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\squid_auto\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\squid_nlb_central\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\squid_nlb_central\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\storage-gateway\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\storage-gateway\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\user_generic\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\user_generic\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\utility_vm\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\utility_vm\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\vpn_nlb_central\manifest.json (53 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\vpn_nlb_central\manifest.yaml
# → Processing gen3-terraform-master\tf_files\aws\waf\manifest.json (61 bytes)
#   ✓ Wrote gen3-terraform-master\tf_files\aws\waf\manifest.yaml
# → Processing gen3-terraform-master\tf_files\gen3\plan.json (0 bytes)
#   • Skipping empty file.

# %% [markdown]
# Merge all Yaml files into in a folder to a single file

# %%
import os
import glob
# recursively merge all .yaml files in a directory
def merge_yaml_files(directory: str = '.', output_file: str = 'merged.yaml'):
    if not os.path.isdir(directory):
        raise FileNotFoundError(f"Directory not found: {directory!r}")

    # Recursively find all .yaml files
    pattern = os.path.join(directory, '**', '*.yaml')
    files = glob.glob(pattern, recursive=True)
    if not files:
        print(f"No YAML files found in {directory!r}.")
        return

    merged_data = {}
    for path in files:
        size = os.path.getsize(path)
        print(f"→ Processing {path} ({size} bytes)")
        if size == 0:
            print(f"  • Skipping empty file.")
            continue

        with open(path, 'r', encoding='utf-8') as yf:
            data = yaml.safe_load(yf) or {}
            merged_data.update(data)

    with open(output_file, 'w', encoding='utf-8') as yf:
        yaml.dump(merged_data, yf, default_flow_style=False)
    print(f"✓ Merged YAML written to {output_file}")
# # — example invocation —
